# %%
from bs4 import BeautifulSoup as bs

# %% [markdown]
# # 4.26 "World Intellectual Property Day" Knowledge Quiz Question Bank and Answers(4.26“世界知识产权日”知识竞赛试题库及答案-巨学问网)

# %%
html = open('4.26“世界知识产权日”知识竞赛试题库及答案-巨学问网.html','r',encoding='utf8').read()
file = bs(html,'html.parser')
title = file.title.string.strip() if file.title else ''
body = '\n'.join([p.get_text().strip() for p in file.find_all('p')])
print(body)
# Out:
# 世界知识产权日，由世界知识产权组织于2001年4月26日设立，并决定从2001年起将每年的4月26日定为"世界知识产权日"，目的是在世界范围内树立尊重知识、崇尚科学和保护知识产权的意识，营造鼓励知识创新的法律环境。为方便您开展知识竞赛宣传活动，特整理了包含了单选题20题、多选题10题、判断题10题的题库，并附有答案。
# 一、单选题（共20题）
# 1、下列文件被认为是世界上第一部版权法的是（   ）
# A、1709 年英国的《安娜女王法》
# B、1890 年美国的《谢尔曼反不正当竞争法》
# C、世贸组织的《知识产权协定》
# D、1900 的《巴黎公约》
# 正确答案：A
#
# 2、说知识产权是（   ） ，比较全面。
# A、活着的人的智力成果
# B、自然人的智力成果
# C、自然人或法人的智力成果
# D、公民的智力成果
# 正确答案：C
#
# 3、专利权的地域性是指在（   ）拥有法律保护
# A、权利人所在的民族区域
# B、申请地所在的国家或者地区
# C、权利人所在国家的建交国家或地区
# D、权利人的国籍国或地区
# 正确答案：B
#
# 4、下列选项，哪项中含有保护期限不受时间限制的知识产权？（   ）
# A、商标权
# B、著作权
# C、实用新型专利权
# D、发明专利权
# 正确答案：B
#
# 5、狭义的知识产权包括(    )
# A、工业产权和版权
# B、著作权和商标权
# C、专利权和著作权
# D、邻接权和集成电路布图设计权
# 正确答案：A
#
# 6、作者的传播权包括（   ）
# A、放映权和展览权
# B、人身权和财产权
# C、排他权和独占权
# D、表演者权、录制者权、广播组织权、出版者权
# 正确答案：D
#
# 7、以下属于知识产权范围的是（   ）
# A、石子游戏规则
# B、数学累加方法
# C、作家头脑中的灵感
# D、舞蹈演员的表演
# 正确答案：D
#
# 8、以下属于知识产权性质范围的是（    ）
# A、可触摸性
# B、不可复制性
# C、无形性
# D、永久性
# 正确答案：C
#
# 9、工业产权中的创造性成果权包括（    ）
# A、发明专利权、使用新型权、外观设计权
# B、商标权、商号权
# C、服务标记权、货源标记权、原产地名称权
# D、制止不正当竞争权
# 正确答案：A
#
# 10、以下属于边缘保护对象的是（    ）
# A、外观设计权
# B、商标权
# C、著作权
# D、专利权
# 正确答案：A
#
# 11、广义的版权分为（    ）
# A、人身权和邻接权
# B、作品的创作者权、作品的传播权
# C、财产权和邻接权
# D、人身权和表演者权
# 正确答案：B
#
# 12、以下不是我国民法通则中保护的知识产权形式的是（    ）
# A、著作权、专利权
# B、商标权、发明权
# C、发现权及其他科技成果权
# D、制止不正当竞争权
# 正确答案：D
#
# 13、将营销模式纳入专利保护范围的是那个国家（   ）
# A、荷兰
# B、美国
# C、中国
# D、丹麦
# 正确答案：B
#
# 14、国家知识产权保护的趋势不包括（   ）
# A、知识产权保护的内容和范围不断扩大
# B、知识产权的保护和国际贸易的关系越来越密切
# C、知识产权保护的标准趋向国际化
# D、知识产权的保护趋于国内保护
# 正确答案：D
#
# 15、发明专利的保护期是20 年，起算日期为（   ）
# A、申请日
# B、发明完成日
# C、专利权生效日
# D、专利申请文件公开日
# 正确答案：A
#
# 16、世界上著作权制度大致分为两派，即（   ）。
# A、英国派与美国派
# B、德国派与法国派
# C、英美法系与大陆法系
# 正确答案：A
#
# 17、下列国际公约和多边协定中，没有著作权保护内容的是（   ）
# A、《巴黎公约》
# B、《伯尔尼公约》
# C、《世界版权公约》
# D、《知识产权协定》（TRIPS）
# 正确答案：A
#
# 18、在下列保护知识产权的国际公约中，最先规定保护驰名商标的是(    )
# A、伯尔尼公约
# B、TRIPS协定
# C、商标国际注册马德里协定
# D、巴黎公约
# 正确答案：D
#
# 19、根据《著作权法》，表演者对其表演所享有的权利是（  ）。
# A、表演权
# B、表演者权
# C、肖像权
# 正确答案：C
#
# 20、商业秘密受保护的条件中不包括（   ）
# A、未公开性
# B、创造性
# C、实用性
# D、保密性
# 正确答案：A
#
# 二、判断题（共10题）
# 1、当事人请求处理或者调解专利纠纷的.由被请求人所在地或者侵权行为地的
# 管理专利工作的部门管辖。
# 正确答案：正确
#
# 2、专利权不能作价投资入股或者质押贷款。
# 正确答案：错误
#
# 3、当事人对管理专利工作的部门作出的行政处理决定不服的.可以依《中华人
# 民共和国民事诉讼法》向人民法院提起诉讼。
# 正确答案：错误
#
# 4、专利权被宣告无效后，继续在制造或者销售的产品上标注专利标记的行为属
# 于冒充专利行为。
# 正确答案：正确
#
# 5、假昌他人专利的，除依法承担民事责任外.构成犯罪的。依法追究刑事责任。
# 正确答案：正确
#
# 6、管理专利工作的部门应当事人的请求.可以就侵犯专利仅的赔偿数额进行处
# 理。
# 正确答案：错误
#
# 7、专利申请权和专利权归属纠纷以及发明人、设计人资格纠纷依法都不能进行
# 调解。
# 正确答案：正确
#
# 8、未经专利权人许可.在广告或者其它宣传资料中使用他人的专利号。使人将
# 所涉及的技术误认为是他人的专利技术的行为，属于假冒他人专利行为。
# 正确答案：正确
#
# 9、管理专利工作的部门可以参与向社会推销专利产品等经营活动。
# 正确答案：正确
#
# 10、当事人对专利侵权纠纷.可以请求管理专利工作的部门处理.也可以直接向
# 人民法院提起诉讼。
# 正确答案：正确
#
# 三、多选题（共10题）
# 1、广义的知识产权分为三大部分，他们是指：（      ）
# A、工业产权
# B、版权
# C、对边缘保护对象的保护权
# D、相邻权
# 正确答案：ABC
#
# 2、知识产权的性质包含以下的那些（      ）。
# A、无形性、专有性
# B、地域性、时间性
# C、可复制性
# D、独占性、排他性
# 正确答案：ABCD
#
# 3、根据著作权法的规定，著作权人享有的复制权等财产权可通过以下哪几项方式行使？（       ）
# A、许可他人行使
# B、转让给他人行使
# C、自己行使
# D、授权著作权集体管理组织行使
# 正确答案：ABCD
#
# 4、下列哪些使用作品的行为，除著作权人声明不许使用的外，可以不经著作权人许可，但应当支付报酬？（       ）
# A、将报纸期刊登载的文章汇编成图书出版
# B、将文字作品片断编入中小学教科书
# C、将期刊上的作品在报纸上转载
# D、为学习研究目的而使用作品
# 正确答案：ABC
#
# 5、1999 年常某创作了随笔《生命的留言》，由《人生》杂志分六期全文登载，不久常某病逝。此书的下列著作权权项中可由常某继承人享有的是（       ）
# A、发表权
# B、署名权
# C、改编权
# D、翻译权
# 正确答案：ACD
#
# 6、申请专利的发明创造在申请日前六个月内不丧失新颖性的情形包括（      ）
# A、在中国政府主办或者承认的国际展览会上首次展出的
# B、在国务院有关主管部门或者全国性学术团体组织召开的学术、技术会议上首次发表的
# C、申请人在国内外学术刊物上首次发表的
# D、承担保密义务的他人未经申请人同意而泄露其内容的
# 正确答案：ABD
#
# 7、下列选项中哪些属于我国《专利法》规定不授予专利权的发明创造（      ）
# A、动物新品种
# B、新烹饪调料
# C、高血压治疗新方法
# D、超导新技术
# 正确答案：ACD
#
# 8、我国的知识产权政策和措施包括（       ）。
# A、健全工作机制，落实政府责任
# B、完善法律法规，改善性质执法与刑事司法的衔接
# C、开展集中打击的专项行动
# D、开展跨区域执法协助和国际合作
# 正确答案：ABD
#
# 9、依据我国著作权法，享有出租权的有（　　   ）
# A、录音制品的制作者
# B、软件著作权人
# C、电影作品的著作权人
# D、录像作品的著作权人
# 正确答案：ABCD
#
# 10、在下列情形中属于合理使用的有（　     ）
# A、在美术书中汇编他人已经发表的美术作品
# B、录音制作者使用他人合法录制为录音制品的音乐作品制作录音制品
# C、将已发表的作品改成盲文出版
# D、为个人欣赏，使用他人已经发表的作品
# 正确答案：CD
# 售前一对一直聊获取活动方案及报价
# 感谢您的关注，当前客服人员不在线，请填写一下您的信息，我们会尽快和您联系。
# 可以介绍下你们的产品么？
# 你们是怎么收费的呢？
# 现在有优惠活动么？

# %%
import re
import json
import pandas as pd


question = re.findall(r"\d+、(.*?)正确答案",body,re.S)

ans = re.findall(r"(正确答案.*?)\s+",body,re.S)

# %%
with open("4.26世界知识竞赛问题答案js.json","w",encoding='utf-8') as f7:
    for i in range(0,len(question)):
        q,a = question[i],ans[i]
        d = {"question":q,"answer":a}
        f7.write(json.dumps(d,ensure_ascii=False)+"\n")

# %% [markdown]
# # April 2022 Knowledge of Intellectual Property Law Self-study Exam Questions and Reference Answers(2022年4月00226知识产权法自考试题及参考答案 - 知乎)

# %%
html = open('2022年4月00226知识产权法自考试题及参考答案 - 知乎.html','r',encoding='utf8').read()
file = bs(html,'html.parser')
title = file.title.string.strip() if file.title else ''
body = '\n'.join([p.get_text().strip() for p in file.find_all('p')])

# %%
import re
import json
import pandas as pd
#提取题目

question = re.findall(r"\d+、(.*?)参考答案",body,re.S)

ans = re.findall(r"(参考答案.*?)\s+",body,re.S)

# %%
with open("2022年4月00226知识产权法自考试题及参考答案js.json","w",encoding='utf-8') as f7:
    for i in range(0,len(question)):
        q,a = question[i],ans[i]
        d = {"question":q,"answer":a}
        f7.write(json.dumps(d,ensure_ascii=False)+"\n")

# %% [markdown]
# # 2023 Intellectual Property Public Legal Knowledge Quiz Question Bank with Answers(2023知识产权普法知识竞赛题库附答案)

# %%
html = open('2023知识产权普法知识竞赛题库附答案.html','r',encoding='utf8').read()
file = bs(html,'html.parser')
title = file.title.string.strip() if file.title else ''
body = '\n'.join([p.get_text().strip() for p in file.find_all('p')])
print(body)
# Out:
# 知识产权，是“基于创造成果和工商标记依法产生的权利的统称”。最主要的三种知识产权是著作权、专利权和商标权，其中专利权与商标权也被统称为工业产权。下面是小编给大家分享的一些有关于2023知识产权普法知识竞赛题库附答案的内容，希望能对大家有所帮助。
# 1、甲乙二人共同提交的专利被授予了专利权。甲乙事先没有任何约定,在未经乙同意的情形下,根据我国现行专利法及其实施细则的规定,甲的下列哪种做法符合相关规定。()
# A、单独实施该专利
# B、放弃该专利权
# C、将该专利权质押给丙
# 答案:A
# 2、专利权人应当自何时起缴纳年费?()
# A、提出申请的当年
# B、提出实质审查请求的当年
# C、被授予专利权的当年
# 答案:C
# 3、甲在创作专著《与上帝接吻》的过程中,乙提供了一些参考资料。作品完成后,由丙出版社发行。该作品的著作权归()所有。
# A、甲
# B、乙
# C、丙
# 答案:A
# 4、恶意抢注他人驰名商标的,驰名商标所有人可以请求撤销该注册商标的时间限制为()。
# A、不受时间限制
# B、3年
# C、5年
# 答案:A
# 5、宣告无效的发明专利权视为()。
# A、自始即不存在
# B、自宣告无效日起即不存在
# C、自发明专利申请公布日起即不存在
# 答案:A
# 6、我国著作权法施行于()。
# A、1990年9月7日
# B、1991年7月1日
# C、1991年6月1日
# 答案:C
# 7、我国商标法施行于()。
# A、1983年5月1日
# B、1983年1月1日
# C、1983年3月1日
# 答案:C
# 8、申请专利在申请日以前6个月之内发生如下哪一种情形的,不丧失新颖性。()
# A、在中国政府主办或者承认的国际展览会上首次展出的
# B、在学术期刊上首次发表的
# C、自己上传到互联网上的
# 答案:A
# 9、全国知识产权维权援助与举报投诉公益服务电话是()。
# A、12328
# B、12329
# C、12330
# 答案:C
# 10、2023年是第几个世界知识产权日()。
# A、第十九个
# B、第二十个
# C、第二十三个
# 答案:C
# 11、乙公司委托甲公司研发某产品,甲公司指定员工田某承担此项研发任务,田某在研发过程中完成了一项发明创造。在没有任何约定的情形下,该发明创造申请专利的权利属于谁?()
# A、田某
# B、甲公司
# C、乙公司
# 答案:B
# 12、《中华人民共和国专利法》何时实施()。
# A、1983年4月1日
# B、1984年4月1日
# C、1985年4月1日
# 答案:C
# 13、今年全国知识产权活动周主题是()
# A、倡导创新文化尊重知识产权
# B、加强知识产权法治保障、有力支持全面创新(正确答案)
# C、创新创造改变生活知识产权竞争未来
# 答案:B
# 14、今年世界知识产权日的主题是()
# A、创新将全世界联系在一起
# B、创新改变生活
# C、女性和知识产权:加速创新创造
# 答案:C
# 15、专利权人与被许可方签订一份专利实施许可合同。在该合同约定的时间和地域范围内,专利权人不得在许可任何第三人以此相同的方法实施该项专利,但专利权人却可以自己实施,则该许可权是()。
# A、交叉实施许可权
# B、排他实施许可权
# C、普通实施许可权
# 答案:B
# 16、知识产权是指公民、法人或其他组织对其智力劳动成果依法取得的()权利。
# A、专有
# B、专用
# C、垄断
# 答案:A
# 17、在下列何种情况下,申请专利的发明或实用新型,如在申请日以前有同样的发明或实用新型并不丧失新颖性?
# A、在国内出版物上公开发表过
# B、在国外公开使用的
# C、在国内公开使用的
# 答案:B
# 18、现行《专利法》是2008年12月27日第()次修改的。
# A、三
# B、二
# C、一
# 答案:A
# 19、我国发明、实用新型和外观设计三种专利的保护期限分别是()、()和()年。
# A、20年、10年、10年
# B、20年、10年、8年
# C、15年、8年、8年
# 答案:A
# 20、《知识产权强国建设纲要(2021-2035年)中提到的发展目标是到()年,知识产权强国建设取得明显成效,知识产权保护更加严格,社会满意度达到并保持较高水平,知识产权市场价值进一步凸显,品牌竞争力大幅提升,专利密集型产业增加值占GDP比重达到()%,版权产业增加值占GDP比重达到()%,知识产权使用费年进出口总额达到()亿元,每万人口高价值发明专利拥有量达到()件(上述指标均为预期性指标)。
# 答案:2025、13、7.5、3500、12
# 21、建设便民利民的知识产权公共服务体系,要深入推进“()”政务服务,充分利用新技术建设智能化专利商标审查和管理系统,优化审查流程,实现知识产权政务服务“()”和“()”服务。
# 答案:互联网+、一网通办、一站式
# 22、知识产权保护工作关系国家()大局,只有严格保护知识产权,才能优化营商环境、建设更高水平开放型经济新体制。知识产权保护工作关系(),只有严格保护知识产权,才能有效保护我国自主研发的关键核心技术、防范化解重大风险。
# 答案:对外开放、国家安全
# 23、党的二十大报告中强调要深化科技体制改革,深化科技评价改革,加大()投入,加强()法治保障,形成支持()的基础制度。[填空题]*
# 答案:多元化科技、知识产权、全面创新
# 24、党的二十大报告明确提出要加快构建新发展格局,着力推动()发展,()是引领发展的第一动力,()作为国家发展战略性资源和国际竞争力核心要素的作用更加凸显。
# 答案:高质量、创新、知识产权
# 25、申请注册的商标,应当有显著特征,便于识别,并不得与他人在先取得的合法权利相冲突。合法的在先权利一般包括()
# A、肖像权
# B、姓名权
# C、著作权
# D、外观设计权
# 答案:ABCD
# 26、外观设计专利权人享有()等项权利。
# A、独占实施权
# B、放弃权和标记权
# C、转让权和许可使用权
# D、进口权
# 答案:ABCD
# 27、下列行为中,不视为侵犯专利权的行为有()
# A、善意侵权
# B、先用权
# C、首次销售
# D、临时过境
# 答案:BCD
# 28、下列属于知识产权保护协议的保护范围的有()
# A、工业产品外观设计和专利
# B、地理标志
# C、邻接权
# D、集成电路布图设计专利法知识
# 答案:ABCD
# 29、在同一种商品上,将与他人的注册商标近似的标志作为商品装潢使用,误导公众的,属于()。
# A、侵犯注册商标专用权的行为
# B、商标使用违法行为
# C、商标使用不妥行为
# D、不是违法行为
# 答案:A
# 30、世界知识产权组织简称是()
# A、WCT
# B、WIPO
# C、WPPT
# D、WTO
# 答案:B
# 31、关于知识产权法的性质,下列表述正确的是()
# A、是一个独立的法律部门
# B、属于民法
# C、属于经济法
# D、属于商法
# 答案:B
# 32、知识产权法保护的对象是()
# A、非物质信息
# B、无形物
# C、财产权
# D、人身权
# 答案:A
# 33、知识产权主要包括()和()两部分
# A、专利权;著作权
# B、工业产权;著作权
# C、商标权;专利权
# D、著作权;商标权
# 答案:B
# 34、商标使用的文字、图形或组合应该具有怎样的特征?()
# A、新颖性
# B、实用性
# C、显著性
# D、独特性
# 答案:C
# 35、专利保护期限从哪一天开始计算?()
# A、颁发专利证书日
# B、申请日
# C、授权公告日
# D、收到回执日
# 答案:B
# 36、下列情形中,可以成为发明人的是()
# A、只是为物质条件提供方便的人
# B、只是负责组织工作的人
# C、只是对发明创造的实质性特点作出了创造性贡献的人
# D、只是从事其他辅助工作的人
# 答案:C
# 37、专利申请权和专利权是否可以转让?
# A、是
# B、否
# 答案:A
# 38、发明,是指对产品、方法或者其改进所提出的新的()
# A、技术方案
# B、科学发现
# C、科学思想
# D、设计
# 答案:A
# 39、我国专利分为发明、实用新型、外观设计三种类型,其保护年限分别为()年、()年、()年。
# A、15;10;10
# B、15;10;5
# C、20;10;10
# D、20;10;15
# 答案:D
# 40、知识产权维权援助与举报投诉热线是()。
# A、12315
# B、12330
# C、12333
# D、12306
# 答案:B
# 41、我国知识产权周是每年的(),2023年的主题是“()”
# A、4月20-4月26;加强知识产权法治保障,有力支持全面创新
# B、4月20-4月26;全面开启知识产权强国建设新征程
# C、4月24-4月28;知识产权与健康中国
# D、4月24-4月28;全面加强知识产权保护,推动构建新发展格局
# 答案:A
# 42、世界知识产权日是每年的(),2023年活动的主题是“()”
# A、4月21日;数字创意重塑文化
# B、4月23日;因乐而动,因乐维权
# C、4月26日;女性和知识产权:加速创新创造
# D、4月27日;法治,创新
# 答案:C
# 以上就是小编为大家整理有关于2023知识产权普法知识竞赛题库附答案的相关内容，如果您想要了解更多信息，可持续关注我们。
# 【2023知识产权普法知识竞赛题库附答案】相关推荐文章:
# 2023第四届应急管理普法知识竞赛题库及答案大全
# 精选知识产权知识竞赛试题题库及答案
# 2023中国普法每日知识竞赛答题答案
# 第四届应急管理普法知识竞赛题库及答案
# 防疫知识竞赛题库及答案2023

# %%
import re
import json
import pandas as pd
#提取题目

question = re.findall(r"\d+、(.*?)答案:",body,re.S)

ans = re.findall(r"(答案:.*?)\s+",body,re.S)

# %%
with open("2023知识产权普法知识竞赛题库附答案js.json","w",encoding='utf-8') as f7:
    for i in range(0,len(question)):
        q,a = question[i],ans[i]
        d = {"question":q,"answer":a}
        f7.write(json.dumps(d,ensure_ascii=False)+"\n")

# %% [markdown]
# # Selected Intellectual Property Knowledge Quiz Question Bank and Answers（精选知识产权知识竞赛试题题库及答案 _ 爱作业）

# %%
html = open('精选知识产权知识竞赛试题题库及答案 _ 爱作业.html','r',encoding='utf8').read()
file = bs(html,'html.parser')
title = file.title.string.strip() if file.title else ''
body = '\n'.join([p.get_text().strip() for p in file.find_all('p')])
body = re.sub("√","正确",body)
body = re.sub("×","错误",body)
print(body)
# Out:
# 知识产权是指智力创造成果：发明、文学和艺术作品，以及商业中使用的符号、名称、图像和外观设计。下面是小编给大家分享的一些有关于精选知识产权知识竞赛试题题库及答案的内容，希望能对大家有所帮助。
# 1、知识产权是法人通过智力劳动所创造的智力成果而依法确认享有的权利（ ）错误
# 2、世界上大多数国家承认著作权属于知识产权的范畴（ ）正确
# 3、世界上大多数国家不认为反不正当竞争法属于知识产权法的范畴（ ）错误
# 4、到2006年年底，约有近200个国家参加了《建立世界知识产权组织公约》（ ）正确
# 5、世界上大多数国家承认科学发现属于知识产权的范畴（ ）正确
# 6、版权是作品创作者的权利（ ）
# 7、版权又称为著作权（ ）正确
# 8、版权的邻接权又称为与版权相关的权利（ ）正确
# 9、版权的邻接权即是出版者权（ ）错误
# 10、版权的邻接权是作品传播者的权利（ ）正确
# 11、专利权即是发明专利权（ ）错误
# 12、发明权即是科学发现权（ ）错误
# 13、发明是指利用已知的科学理论、自然规律、科学技术所创造的新事物、新产品、新方法，特别是科学技术方面的新成就（ ）正确
# 14、外观设计强调的是保护文学艺术品（ ）错误
# 15、世界上大多数国家对外观设计采用专利法加以保护（ ）错误
# 16、商号是厂商字号的简称，也称为字号或厂商名称（ ）正确
# 17、按照WIPO的规定，地理标志是货源标记和原产地名称的总称（ ）正确
# 18、TRIPS协议是指1994年1月1日生效的世界贸易组织《与贸易有关的知识产权协议》（ ）正确
# 19、WTO对知识产权的定义比WIPO对知识产权的定义外延更宽（ ）错误
# 20、拓扑图是指集成电路布图设计（ ）正确
# 21、商业秘密是指经营者在生产、销售、经营、服务中对外保密，而又不被公众所知悉，能给经营者带来竞争优势的信息（ ）正确
# 22、工业产权可分为三类：创造性成果权、识别性标记权、制止不正当竞争权（ ）正确
# 23、作品创作者权可分为经济权利和精神权利（ ）正确
# 24、邻接权又称为与版权有关的权利，包括表演者权、录制者权、广播组织权、出版者权等（ ）正确
# 25、广义的知识产权分为三大部分：工业产权、版权、外观设计权（ ）错误
# 26、知识产权与一般有形财产权的主要区别在于有没有法定的保护期限（ ）错误
# 27、知识产权是一种法律所确认和保护的权利，属于私权（ ）正确
# 28、发明人的署名权属于知识产权中的人身权（ ）正确
# 29、"知识产权"是外来语的意译（ ）正确
# 30、我国首次使用"知识产权"此概念始于1973年（ ）正确
# 31、迄今为止有关国际公约是从划定知识产权所包括的权利范围来对知识产权加以定义的（ ）正确
# 32、原产地名称不是《巴黎公约》明确保护的对象之一（ ）错误
# 33、货源标记又称为产地标记（ ）正确
# 34、产地标记和产地标志是不同概念（ ）产地标记是指标示某产品生产于某地方的标记，产地标记又称“地产标志”，是指用以标明某种产品产地的标记。产地标志，亦称为原产地名称，即一个国家、地区或地方的地理名称，用以表明某类产品的原产地。在国际工业产权贸易中，产地标志的问题十分重要。错误
# 35、按照WIPO的规定，地理标志即是原产地名称（ ）错误
# 36、商业标记不包括工业品外观设计（ ）正确
# 37、创造性成果权不包括专利权（ ）错误
# 38、狭义的知识产权包括工业产权和著作权（ ）正确
# 39、创造性成果权包括商标权（ ）错误
# 40、创造性成果权包括实用新型权（ ）正确
# 41、创造性成果权包括外观设计权（ ）正确
# 42、识别标记权包括实用新型权（ ）错误
# 43、识别标记权包括发明（ ）错误
# 44、识别标记权包括商号权（ ）正确
# 45、识别标记权包括服务标记权（ ）正确
# 46、识别标记权包括商标权（ ）正确
# 47、识别标记权包括货源标记权（ ）正确
# 48、识别标记权包括原产地名称权（ ）正确
# 49、一项智力成果能否取得知识产权保护，依各国法律不同而不同（ ）正确
# 50、一项合法获得的知识产权，在全世界内都有效（ ）错误
# 51、一项智力成果的知识产权在一国失效意味着在另一国也已失效（ ）错误
# 52、一项智力成果的知识产权在一国构成侵权意味着在另一国也属侵权（ ）错误
# 53、知识产权的专有性又可称为独占性（ ）正确
# 54、知识产权的专有性又可称为排他性（ ）正确
# 55、涉及知识产权一般适用财产取得地法（ ）错误
# 56、涉及知识产权一般适用物之所在地法（ ）错误
# 57、涉及知识产权一般适用权利登记地法（ ）正确
# 58、涉及知识产权一般适用权利主张地法（ ）正确
# 59、知识产权有法定的保护期限（ ）正确
# 60、知识产权失效只是其权利的丧失，智力成果仍在（ ）正确
# 61、知识产权失效，则智力成果就失去了原有的使用价值（ ）错误
# 62、对知识产权规定保护期限，是兼顾权利所有人的利益及社会利益（ ）正确
# 63、知识产权的可复制性又称为工业再现性（ ）正确
# 64、知识产权的可复制性是知识产权被视为财产权的基本原因之一（ ）正确
# 65、由于知识产权的客体具有可复制性，才使知识产权向其他客体物质载体的价值转移成为可能（ ）正确
# 66、知识产权的可复制性是知识产权最基本的性质（ ）错误
# 67、知识产权一般表现为对某项权利的占有（ ）正确
# 68、知识产权的利用和转移一般不引起相关有形物的消耗和转移（ ）正确
# 69、知识产权的标的具有可分别利用性（ ）正确
# 70、对知识产权的侵害行为不一定直观和明显（ ）正确
# 71、知识产权的专有性又称为独占性、排他性或垄断性（ ）正确
# 72、在知识产权权利的有效期内，未经权利人许可，在规定领域内，任何人一般不得利用此项权利（ ）正确
# 73、在知识产权权利的有效期内，未经权利人许可，任何人均不得利用此项权利（ ）错误
# 74、对于一项智力成果，国家所授予的某一类型知识产权应当是唯一的（ ）正确
# 75、WTO一共设立了货物贸易理事会、服务贸易理事会及与贸易有关的知识产权理事会（ ）正确
# 76、TRIPS协议是当前世界范围内知识产权保护领域中的国际公约，它涉及面广、保护水平高、保护力度大、制约力强（ ）正确
# 77、TRIPS协议于1995年1月1日起生效（ ）正确
# 78、我国没有做出在我国民商法范围内涉外领域可以直接适用TEIPS的承诺（ ）正确
# 79、我国法院审理涉及知识产权的案件可以直接适用WTO有关协定（ ）错误
# 80、知识产权所涉及的人身权包括商号权（ ）正确
# 81、WTO一共设立了货物贸易理事会、服务贸易理事会及与贸易有关的知识产权理事会三个理事会（ ）正确
# 82、TRIPS协议是当前世界范围内知识产权保护领域中的国际公约（ ）正确
# 83、国际私法一般不包括冲突规范（ ）错误
# 84、知识产权法不涉及国际私法问题（ ）错误
# 85、宪法中没有与知识产权保护有关的内容（ ）错误
# 86、知识产权法属于经济法法律部门中一个法律制度（ ）错误
# 87、知识产权法属于民法法律部门中一个法律制度（ ）正确
# 88、我国内地主要的知识产权法律包括《中华人民共和国商标法》、《中华人民共和国专利法》及《中华人民共和国著作权法》等法律（ ）正确
# 89、迄今我国缔结了《世界版权公约》、《保护工业产权巴黎公约》及TRIPS协议等国际公约（ ）正确
# 90、《巴黎公约》的基本原则包括了国民待遇原则（ ）正确
# 91、《巴黎公约》的基本原则包括了透明度原则（ ）错误
# 92、《伯尔尼公约》保护的经济权利包括署名权（ ）错误
# 93、《伯尔尼公约》保护的精神权利包括复制权（ ）错误
# 94、TRIPS明确对于知识产权有关程序的行政终局决定，均应接受司法或准司法当局的审查，或有机会提交司法当局复审（ ）正确
# 95、专利权是一种知识产权，它具有狭义知识产权的全部特性。（ ）正确
# 96、专利法是调整因发明创造而产生的各种社会关系的法律规范的总和。（ ）正确
# 97、专利法与专利制度是同一概念。（ ）错误
# 98、世界各国专利法都将发明、实用新型和外观设计规定为专利权的客体。（ ）错误
# 99、所谓发明是指对产品、方法或者其改进所提出的新的理论方案。（ ）错误
# 100、专利法所称的实用新型是指对产品的形状、构造或者其组合所提出的新的技术方案。（ ）正确
# 101、发明专利只保护产品。（ ）错误
# 102、发明专利只保护方法。（ ）错误
# 103、实用新型专利保护的是方法。（ ）错误
# 104、实用新型专利只保护产品。（ ）正确
# 105、将现有技术中已知的材料应用于具有形状、构造的产品上，可以成为发明专利的保护客体。（ ）错误
# 106、将现有技术中已知的材料应用于具有形状、构造的产品上，若不属于对材料本身提出的技术方案，可以成为实用新型专利的保护客体。（ ）正确
# 107、无确定形态的产品不能成为实用新型的保护客体。（ ）正确
# 108、实用新型保护的产品应当是经过产业方法制造的、占据一定空间的实体。（ ）正确
# 109、发明只保护经过产业方法制造的、占据一定空间的实体的产品。（ ）错误
# 110、外观设计保护的是经过产业方法制造的、占据一定空间的实体的产品。（ ）错误
# 111、产品表面的纯粹的文字、符号、图表或者其结合的新方案，不属于实用新型的保护客体。（ ）正确
# 112、产品表面的纯粹的文字、符号、图表或者其结合的新方案，不属于外观设计的保护客体。（ ）正确
# 113、产品表面的纯粹的文字、符号、图表或者其结合的新方案，可以成为外观设计的保护客体。（ ）正确
# 114、直接作用于人体的医疗器具被授予专利权时，意味着该专利产品具备了市场准入条件。（ ）错误
# 115、直接作用于人体的医疗器具被授予专利权时，不意味着该专利产品具备了市场准入条件。（ ）正确
# 116、已有材料的组合属于产品构造。（ ）正确
# 117、单纯材料的替换不属于产品构造的变化，不属于实用新型的保护范围。（ ）正确
# 118、物质的分子结构、组分的变化不属于实用新型。（ ）正确
# 119、复合层不属于产品构造，不能成为实用新型的保护客体。（ ）错误
# 120、外观设计必须具有直接可视性。（ ）正确
# 121、外观设计的载体须是用产业方法生产出来的物品。（ ）正确错误
# 122、外观设计的载体须是用产业方法生产出来的物品须有固定的形状。（ ）正确
# 123、授予外观设计的产品须是用产业方法生产出来的有固定形状的具有独立使用价值的产品。（ ）正确
# 124、外观设计的构成要素是产品形状或图案。（ ）正确
# 125、外观设计指对产品的形状、图案或者其结合以及色彩与形状、图案的结合所作出的富有美感的并适于工业应用的新设计。（ ）正确
# 126、外观设计强调和保护的是艺术性。（ ）错误
# 127、我国专利法对三种专利的新颖性规定是一样的。（ ）错误
# 128、技术方案只要在申请日前已经公开，一律丧失新颖性。（ ）错误
# 129、某项技术即使是由无能力理解该项技术内容的人员所知，也不再具有新颖性。（ ）错误
# 130、抵触申请是指在一项专利申请的申请日以前由他人向同一专利局提出过申请、而又在该申请日之后(含申请日)公布的、同样技术内容的专利申请。（ ）正确
# 131、在先申请没有公开的，不影响后一申请的新颖性，不成为后一申请的抵触申请。（ ）正确
# 132、发明的创造性是指同申请日以前已有的技术相比，具有突出的实质性特点和显著进步。（ ）正确
# 133、发明的创造性是指同申请日以前已有的技术相比，具有实质性特点和进步。（ ）正确错误
# 134、实用新型的创造性是指同申请日以前已有的技术相比，具有实质性特点和进步。（ ）正确
# 135、实用新型的创造性是指同申请日以前已有的技术相比，具有突出的实质性特点和显著进步。（ ）错误
# 136、外观设计的创造性是指同申请日以前已有的设计相比，具有突出的实质性特点和显著进步。（ ）错误
# 137、外观设计的创造性是指同申请日以前已有的设计相比，具有实质性特点和进步。（ ）错误
# 138、一项专利申请的申请日以前由他人向同一专利局提出过申请、而又在该申请日之后(含申请日)公布的、同样技术内容的专利申请会导致后一专利申请的创造性消失。（ ）错误
# 139、创造性所要求的实质性特点是其具有所属技术领域普通技术人员在现有的基础上通过逻辑分析、推理无法得到的技术特征。（ ）正确
# 140、实用性是发明或实用新型能够制造或者使用，并能产生积极效果。（ ）正确
# 141、实用性是发明、实用新型、外观设计能够制造或者使用，并能产生积极效果。（ ）正确
# 142、我国专利法对外观设计的实用性作出了明确规定。（ ）错误
# 143、我国专利法对实用性要求是可实施性、再现性、工业应用性。（ ）正确
# 144、我国专利法对外观设计未作实用性要求。（ ）错误
# 145、我国专利法规定，凡是在国内外出版物上公开发表过，在国内外公开使用过或以其他方式为公众所知，则该技术方案不具有新颖性。（ ）错误
# 146、专利书面申请原则是世界各国通行的原则。（ ）正确
# 147、一件发明或者实用新型专利申请应当限于一项发明或实用新型。（ ）正确
# 148、一件外观设计专利申请应当限于一种产品所使用的一项外观设计。用于同一类别并且成套出售或者使用的产品的两项以上的外观设计专利，可以作为一件申请提出。（ ）正确
# 149、两个以上的申请人分别就同样的发明创造申请专利的，专利权授予最先发明的人。（ ）错误
# 150、两个以上的申请人分别就同样的发明创造申请专利的，世界各国家都采取专利权授予先申请的人。（ ）正确
# 151、申请人自外观设计在中国第一次提出专利申请之日起十二个月内，又向国务院专利行政部门提出专利申请的，可以享有优先权。（ ）错误
# 152、申请人自发明或实用新型在外国提出专利申请之日起六个月内，又在中国就相同主题提出专利申请的，可以享有优先权。（ ）错误
# 153、申请人要求本国优先权的，其在先申请自后一申请提出之日起即被视为撤销。（ ）错误
# 154、申请人在一件专利申请中，只能要求一项优先权。（ ）错误
# 155、申请专利的文件中的说明书应当对发明或实用新型作出清楚、完整的说明，以社会公众依照说明书能够实现为准。（ ）错误
# 156、专利保护之所以强调公开原则，是为了使受专利保护的技术能够迅速得到传播，加以推广利用，同时避免他人再对此同一技术方案进行重复性的开发、研究，浪费人力、物力。（ ）正确
# 157、申请实用新型专利，除提交说明书外，在必要的时候应当有附图。（ ）错误
# 158、申请专利的说明书必须支持权利要求书。（ ）正确
# 159、申请人有权对专利申请文件进行修改，但修改不得超出原申请文件范围。（ ）正确
# 160、使用不当或滥用会违反国家法律的发明创造，不能被授予专利权。（ ）错误
# 161、法律禁止公开自由销售的产品的发明创造，不能被授予专利权。（ ）错误
# 162、社会公德是指公众普遍公认并接受的道德伦理观念、道德标准和风俗习惯。（ ）正确
# 163、公共利益是指国家和社会的正常的秩序、国家和公众共同的利害关系、公众的人身安全保障等。（ ）正确
# 164、按照国际权利用尽原则，专利权在一国内权利用尽，就意味着专利权在国际范围内的权利用尽。（ ）错误
# 165、被授予专利权的企业事业单位许可其他单位或个人实施专利的应当从收取的使用费中，纳税后提取不低于2%作为报酬支付发明人或设计人。（ ）错误
# 166、商品的"平行进口"指合法制造和销售的、与国内某权利持有人持有的相同知识产权的商品进口。（ ）正确
# 167、未经专利权人许可的专利产品的平行进口一定违法。（ ）错误
# 168、周边限定原则要求以权利要求书为中心，结合说明书和附图，考虑发明创造的目的和性质来确定专利的保护范围。（ ）错误
# 169、一项发明或实作新型可以有多项独立权利要求。（ ）正确
# 170、等到同原则是指与专利文件记载的技术特征以基本相同的手段，实现基本相同的功能，达到基本相同的效果，并且本领域的技术人员无需经过创造性劳动就能够联想到的特征。（ ）正确
# 171、必要技术特征是为了达成预期的目的和效果，构成一项技术方案必不可少的技术特征。（ ）正确
# 172、外观设计专利的保护范围的确定标准与商标权的保护范围的确定标准相近。（ ）正确
# 173、判断外观设计是否相同相近似的时候，以一般的消费者的水平进行判断。（ ）正确
# 174、判断外观设计是否相同相近似，主要采取直接对比方法进行判断。（ ）错误
# 175、要求优先权的先后两个申请技术主题内容须相同，保护形式须相同。（ ）错误
# 176、要求优先权的申请提出，即意味着在先申请撤回。（ ）错误
# 177、国际优先权的实现以撤回在先申请为条件。（ ）错误
# 178、任何依照专利技术制造出来的产品经过一经售出后，专利权利即用尽。（ ）错误
# 179、专利权人必须在其专利产品或者产品的包装上标明专利标记和专利号。（ ）错误
# 180、涉及半导体技术的发明创造不得强制许可。（ ）错误
# 181、专利权利穷竭是指合法制造的受知识产权保护的产品，在首次销售后，权利人就失去了对该产品本身的再次销售、使用等控制、制约的权利。（ ）错误
# 182、凡未经专利权人许可而实施专利的行为就是专利侵权行为。（ ）错误
# 183、专利侵权是指在专利权有效地域和有效期限内，未经专利权人许可实施其专利的任何行为。（ ）错误
# 184、专利侵权是指在专利权有效地域和有效期限内，未经专利权人许可，为生产经营的目的而实施其专利的行为。（ ）正确
# 185、冒充专利是指未经专利权人许可，在自己的商品或与其相关的宣传中使用他人的专利标记或专利号，使人误认为该产品是已经取得专利权利的专利产品或依照专利方法直接获得的产品的行为。（ ）错误
# 186、为生产经营目的使用或者销售不知道是未经专利权人许可而制造并售出的专利产品或者依照专利方法直接获得的产品，能证明其产品合法源的，不构成侵犯专利权行为。（ ）错误
# 187、假冒专利行为的主观过错既可以是故意，也可以是过失。（ ）错误
# 188、在我国，许可他人实施专利必须采取书面合同的方式。（ ）正确
# 189、世界上大多数国家对专利侵权的认定适用过错责任原则。（ ）错误
# 190、世界上大多数国家对直接侵害专利权的行为认定适用无过错责任原则，对间接侵害专利权的行为认定适用过错责任原则。（ ）正确
# 191、为生产经营目的使用或者销售不知道是未经专利权人许可而制造并售出的专利产品或者依照专利方法直接获得的产品，能证明其产品合法源的，属于合理使用。（ ）错误
# 192、以非专利产品冒充专利产品，以非专利方法冒充专利方法的，属于假冒专利行为。（ ）错误
# 193、抵触申请只影响发明和实用新专利申请的新颖性，不影响外观设计的新颖性。（ ）正确
# 194、属于一个总的发明构思的两项以上的发明或实用新型，可以作为一件申请提出。（ ）正确
# 195、商标是指商品的生产者、经营者或服务的提供者为了标明自己、区别他人在自己的商品或服务上使用的可视性标志。（ ）正确
# 196、商标的最基本功能是识别功能。（ ）正确
# 197、商号是经营者在营业上表示自己的名称。（ ）正确
# 198、商号不得转让。（ ）错误
# 199、商号权是一种兼有财产权和人格权属性的工业产权。（ ）正确
# 200、厂标与商标不得相同。（ ）错误
# 201、产地标记可以转让。（ ）错误
# 202、原产地名称可以通过注册成为相对应的证明商标或集体商标。（ ）正确
# 203、商业外观是指对商品外表或者提供的某种服务的场所、用具及服务人员的服装等所设计的独特的外观装饰。（ ）正确
# 204、商品化形象权是指将其真实的名人的形象、虚构人物或动物的艺术形象用于商业目的的独占权。（ ）正确
# 205、我国对商标注册的条件可分为形式条件和实质条件。（ ）正确
# 206、注册商标需要在同一类的其商品上使用的，应当重新提出注册申请。（ ）错误
# 207、申请注册的商标应当具有显著性。（ ）正确
# 208、两个或两个以上的商标注册申请人，同一天在同一种商品或者类似商品上，以相同或者相近似的商标申请注册的，以抽签方式确定申请人并予以公告。（ ）错误
# 209、商标注册人自商标在外国第一次提出商标注册申请之日起6个月内，又在中国就相同商品以同一商标提出注册申请的，可以享有优先权。（ ）正确
# 210、以与他人已经失效一年以上的注册商标相同或相似的商标申请注册，不予核准。（ ）错误
# 211、以不具有功能性的立体商标申请注册，不予核准。（ ）错误
# 212、所有未注册的商标不受法律保护。（ ）错误
# 213、商标注册人的禁用权与其享有的使用权的范围一致。（ ）错误
# 214、注册商标有效保护期满时未提出续展的，一律由商标局注销。（ ）错误
# 215、我国商标法对商标续展时间规定是期满前6个月，期满后给12个月宽展期。（ ）错误
# 216、转让联合商标、防御商标的，受让人应当具备相应的主体资格。（ ）正确
# 217、注册商标转让后，原商标权人仍有权使用。（ ）错误
# 218、转让注册商标的，商标注册人对其在同一种或者类似商品上注册的相同或相近似的商标，应当一并转让。（ ）正确
# 219、转让注册商标的，商标注册人可以保留其在同一种或者类似商品上注册的相同或相近似的商标。（ ）错误
# 220、商标使用许可合同未经备案的，该许可合同不生效。（ ）错误
# 221、注册商标需要改变标志的，应当提出变更申请。（ ）错误
# 222、只有在先商标注册人才有权利对已经注册的商标提出争议。（ ）正确
# 223、注册商标连续2年停止使用，由商标局注销。（ ）错误
# 224、使用注册商标标记，应当标注在商标的左上角或左下角。（ ）错误
# 225、商标注册人许可他人使用注册商标的，许可人应当保证被许可人使用该注册商标的商品的质量。（ ）错误
# 226、注册商标要扩大使用范围，应当提出变更申请。（ ）错误
# 227、连续使用至1993年7月1日的服务商标与他人在相同或者类似的服务上已经注册的服务商标相同或相近似的，可以继续使用。（ ）正确
# 228、商标权的保护范围与商标权的独占使用权范围一致。（ ）错误
# 229、世界上所有注册商标，在我国都受法律保护。（ ）错误
# 230、未在中国注册的商标，一律不受我国商标法的保护。（ ）错误
# 231、商品或服务类似的判断，应以普通消费者对商品或服务的客观认识为准。（ ）错误
# 232、近似商标是指"音""形""意"相同或近似，容易使消费者产生混淆，而又用于同种商品(或服务)或类似商品(或服务)的商标。（ ）正确
# 233、冒充商标是指在商标有效地域和有效期限内，未经商标权人许可，在同类商品(包括服务)上使用与其相同商标的行为。（ ）错误
# 234、驰名商标的认定应遵循"个案处理、被动认定"原则。（ ）正确
# 235、法律对所有驰名商标实行跨类别保护。（ ）错误
# 236、商标法所称相关公众，是指与商标所标识的某类商品或者服务有关的消费者和与前述商品或者服务的营销有密切关系的其他经营者。（ ）正确
# 237、商标近似，是指被控侵权的商标与原告的注册商标相比较，其文字的字形、读音、含义或者图形的构图及颜色。或者其各要素组合后的整体结构相似，或者其立体形状、颜色组合近似，易使相关公众对商品的来源产生误认或者认为其来源与原告注册商标的商品有特定的联系。（ ）正确
# 238、判断组合商标是否是相同商标，既要看商标中文字部分是否完全相同，又要看图形部分是否相同。作为相同的组合商标，其文字部分和图形部分都是完全相同的，不能有明显的差别。（ ）错误
# 239、归责原则是侵权行为构成要件的基础和前提。（ ）正确
# 240、商标被许可人违反许可合同约定，超出被许可使用的商品或者服务的范围、使用期限或者商品数量，使用该注册商标的的行为，既构成违约，同时也构成侵权。（ ）正确
# 241、独占使用许可，是指商标注册人在约定的期间、地域和以约定的方式，将该注册商标仅许可一个被许可人使用，商标注册人依约定不得使用该注册商标。（ ）错误
# 242、排他使用许可，是指商标注册人在约定的期间、地域和以约定的方式，将该注册商标仅许可一个被许可人使用，商标注册人依约定可以使用该注册商标但不得另行许可他人使用该注册商标。（ ）错误
# 243、判断商标侵权能否成立，或者说判断商标违法行为能否构成的最关键、最复杂的问题就是判定商标权的保护范围。（ ）正确
# 244、对于已经核准注册的驰名商标而言，即使被控商标侵权产品(或服务)与注册商标核定使用的产品(或服务)不构成同种商品(或服务)或类似商品(或服务)，但是两个商标构成相同或近似，如果会暗示该商品或服务与注册商标所有人存在某种联系，从而注册商标所有人的利益可能因此受损，应该判定为构成商标侵权。（ ）正确
# 245、销售不知道是侵犯注册商标专用权的商品，能证明该商品是自己合法取得的并说明提供者的，不承担赔偿责任。（ ）正确
# 246、侵犯商标专用权的赔偿数额，为侵权人在侵权期间所获得的利益，或者被侵权人在被侵权期间因被侵权所受到的直接损失。（ ）错误
# 247、对侵犯注册商标专用权的行为，罚款数额为非法经营额3倍以下;非法经营额无法计算的，罚款数额为10万元以下。（ ）正确
# 248、工商行政管理部门对同一侵犯注册商标专用权行为已经给予行政处罚的，人民法院不再受理。（ ）错误
# 249、一般商标侵权主要是指侵害商标权持有人的权益，商标假冒不仅侵害商标权持有人的权益，而且侵害社会公众的利益，具有社会危害性。（ ）正确
# 250、商标中有商品的地理标志，而该商品并非来源于该标志所标示的地区，误导公众的，不予注册并禁止使用;但是，已经善意取得注册的继续有效。（ ）正确
# 251、商标使用许可合同有效期间所发生的注册商标所有权的变动，不能影响商标使用许可合同的.效力。（ ）正确
# 252、定牌加工是指由委托方指定商标，加工方将其指定的商标用于所加工的商品上。（ ）正确
# 253、普通使用许可，是指商标注册人在约定的期间、地域和以约定的方式，许可他人使用其注册商标，并可自行使用该注册商标和许可他人使用其注册商标。（ ）正确
# 254、侵犯商标权人因侵权所得利益或者被侵权人因被侵权所受损失难以确定的，由人民法院根据侵权行为的情节判决给予五十万元以上的赔偿。（ ）错误
# 255、人民法院在确定赔偿数额时，应当考虑侵权行为的性质、期间、后果，商标的声誉，商标使用许可费的数额，商标使用许可的种类、时间、范围及制止侵权行为的合理开支等因素综合确定。（ ）正确
# 256、没有进行认定的商标一定不是驰名商标。（ ）错误
# 257、商标印制是指印刷、制作商标标识的行为。（ ）正确
# 258、商标标识是指与商品配套一同进人流通领域的带有商标的有形载体，包括注册商标标识和未注册商标标识。（ ）正确
# 259、经许可使用他人注册商标的，无须在使用该注册商标的商品上标明被许可人的名称和商品产地。（ ）错误
# 260、使用注册商标，其商品粗制滥造，以次充好，欺骗消费者的，由各级工商行政管理部门分别不同情况.责令限期改正，并可以予以通报或者处以罚款，或者由商标局撤销其注册商标。（ ）正确
# 261、从事商标注册、管理和复审工作的国家机关工作人员玩忽职守、滥用职权、徇私舞弊，违法办理商标注册、管理和复审事项，收受当事人财物，牟取不正当利益，构成犯罪的，依法追究刑事责任;尚不构成犯罪的，依法给予行政处分。（ ）正确
# 262、伪造或者变造《商标注册证》的，依照刑法关于伪造、变造国家机关证件罪或者其他罪的规定，依法追究刑事责任。（ ）正确
# 263、"反向假冒"是指未经商标注册人同意，更换其注册商标并将该更换商标的商品又投重新市场的行为。（ ）正确
# 264、知识产权已经成为当今社会推动各国经济发展的重要资源（ ）正确
# 265、企业的无形资产所占的比重越大，说明企业越缺乏活力（ ）错误
# 266、知识产权贸易包括知识产权许可（ ）正确
# 267、知识产权贸易包括知识产权转让（ ）正确
# 268、知识产权已经成为重要的无形财产（ ）正确
# 269、中国加强知识产权保护在一定程度上是屈服于发达国家的压力（ ）错误
# 270、狭义的知识产权贸易包括知识产权许可（ ）正确
# 271、狭义的知识产权贸易包括知识产权转让（ ）正确
# 272、狭义的知识产权贸易包括知识产权产品贸易（ ）错误
# 273、狭义的知识产权贸易包括知识产权交流（ ）错误
# 274、广义的知识产权贸易还包括知识产权产品贸易（ ）正确
# 275、为了加强知识产权保护，应当树立知识产权的保护意识（ ）正确
# 276、为了加强知识产权保护，应当树立知识产权的竞争意识（ ）正确
# 277、为了加强知识产权保护，应当树立知识产权的跨国意识（ ）错误
# 278、为了加强知识产权保护，应当树立知识产权的发展意识（ ）正确
# 279、国外企业的知识产权管理机构，要负责与本企业有关知识产权的检索、监控、分析的职责（ ）正确
# 280、国外企业的知识产权管理机构，要负责本企业的知识产权审核、申报的职责（ ）正确
# 281、国外企业的知识产权管理机构，要负责本企业知识产权的维护、管理的职责（ ）正确
# 282、国外企业的知识产权管理机构，要负责处理本企业知识产权的侵权谈判、诉讼事宜的职责（ ）正确
# 283、国外企业的知识产权管理机构，要负责所在企业知识产权的经营职责（ ）正确
# 284、国外企业的知识产权管理机构，要负责制定、实施本企业知识产权的战略、计划的职责（ ）正确
# 285、防范知识产权的风险主要有知识产权被侵害的风险（ ）正确
# 286、防范知识产权的风险主要有知识产权侵权指控的风险（ ）正确
# 287、防范知识产权的风险主要有知识产权构建的非关税贸易壁垒的风险（ ）正确
# 288、防范知识产权的风险主要有知识产权失效的风险（ ）错误
# 289、以知识产权构建的非关税壁垒，主要有以知识产权侵权为由，提起诉讼，达到阻止竞争者产品进口的目的（ ）正确
# 290、以知识产权构建的非关税壁垒，主要有以安全的名义，推行与知识产权密切相关的技术标准作为进口产品必须达到的标准，迫使其降低产品竞争力（ ）正确
# 291、以知识产权构建的非关税壁垒，主要有以卫生的名义，推行与知识产权密切相关的技术标准作为进口产品必须达到的标准，迫使其降低产品竞争力（ ）正确
# 292、以知识产权构建的非关税壁垒，主要有以环保的名义，推行与知识产权密切相关的技术标准作为进口产品必须达到的标准，迫使其降低产品竞争力（ ）正确
# 293、知识产权的滥用行为可以是在知识产权的许可协议中设置限制性贸易条款（ ）正确
# 294、知识产权的滥用行为不可能是滥用保护知识产权的执法程序（ ）错误
# 295、知识产权的滥用行为不可能是以构成"侵权"相威胁（ ）错误
# 296、知识产权的滥用行为可以是不合理地限制他人实施其知识产权所保护的智力成果（ ）正确
# 297、限制受让人改进让与人提供的技术不属于设置限制性贸易条款（ ）错误
# 298、限制受让人从其他来源获得与让与人提供的技术类似的技术不属于设置限制性贸易条款（ ）错误
# 299、要求受让人接受并非技术进口必不可少的设备等属于设置限制性贸易条款（ ）正确
# 300、要求受让人为专利支付使用费属于设置限制性贸易条款（ ）错误
# 一、单选题（1’X30）
# 1、世界知识产权组织的简称是（A）
# A.WIPO B.WTOC.WPPTD.WCT
# 2、首次将知识产权问题纳入国际贸易中的国际公约是（A）
# A.《TRIPS协议》 B.《巴黎公约》C.《伯尼尔公约》D.《马德里协定》
# 3、关于知识产权的地位，下列表述中正确的是（A）
# A知识产权属于民法范畴
# 4、不属于知识产权基本特征的是（D）
# A.时间性 B.地域性C.专有性 D.实用性
# 5、依据我国著作权法，图书出版单位的专有出版权在合同中的约定期限最多为（A）
# A.10年B.7年 C.50年D.没有规定
# 6、知名画家甲把自己画的一幅画送给乙，乙一直珍藏在家中，在一次画展中，乙将上述画参展，乙的行为（D）
# A.侵犯了甲的署名权 B.侵犯了甲的展览权 C.侵犯了甲的发行权 D.不侵权
# 7、国画大师李某将自己的传奇人生记录下来，遂请作家王某执笔，某助手张某整理素材。王某以李某的人生经历为素材完成了自传体小说《我的艺术人生》。李某向王某支付了5万元，但未约定著作权的归属。该小说的著作权应当归谁所有？（D）
# A.归王某所有 B.归王某和张某共同所有
# C.归王某、张某和李某三人共同所有D.归李某所有
# 8、甲电视台获得2006年德国世界杯足球赛A队与B队比赛的现场直播权。乙电视台未经许可将甲电视台播放的比赛实况予以转播，丙电视台未经许可将乙电视台转播的实况比赛录制在音像载体上以备将来播放，丁某未经许可将丙电视台录制的该节目复制一份供其儿子观看。下列哪种说法是正确的？（B）
# A.乙电视台侵犯了A队和B队的表演者权B.甲电视台有权禁止乙电视台的转播行为
# C.丙电视台的录制行为没有甲电视台的权利 D.丁的行为侵犯了甲电视台的复制权
# 9、著作权法规定的出租权适用于以下所列哪一类作品？（C）
# A.音乐作品 B.美术作品 C.电视剧D.文字作品
# 10、某大型商场在营业期间，通过录放设备播放音乐CD盘，以营造良好的购物气氛，依著作权法的规定，该商场应当（D）
# A.经该录音制品的制作人许可并支付报酬 B.经音乐作品著作人许可并支付报酬
# C.经音乐作品表演者许可并支付报酬 D.经以上三方许可并支付报酬
# 11、以下所列举的表演者中，依法享有表演者权的是（A）
# A.相声演员、电影演员、服装模特 B.杂技演员、歌唱演员、话剧演员
# C.舞蹈演员、武术表演者、京剧演员 D.体操表演者、音乐演奏者、马戏表演者
# 12、以下对作品的使用行为，属于法定许可使用的是（A）
# A.广播电视台、电视台播放他人已发表的作品
# B.表演者在营业性表演活动中演唱他人已发表的音乐作品
# C.使用他人已发表的摄影作品制作公益性广告
# D. 将他人已发表的作品改为盲文发表
# 13、计算机软件获得著作权保护的条件（D）
# A.具有原创性、可感知性、新颖性 B. 具有原创性、创造性、可再现性
# C.具有显著性、实用性、可再现性 D具有原创性、可感知性、可再现性
# 14、下列可以受专利法保护的对象是（C）
# A.某甲发明的一种高血压病的治疗方法 B.某乙发明的一种游戏规则
# C.某丙发明的一种茶叶的制作方法 D.某丁发明可用于专用于吸食毒.品的工具
# 15、陈某完全利用本单位的实验材料、实验室和不对外公开的技术资料完成了一项发明，对该发明的权利归属，表达正确的是（B）
# A.无论陈某与单位有无特别约定，该项成果都属于单位
# B.原则上讲应归单位所有，但如果单位与陈某对成果的归属有特别约定的，从约定
# C.要看该发明是否属于单位分派给陈某
# D.无论陈某与单位有无特别规定，该项成果都属于陈某
# 16、对发明创造新颖性构成影响的公开是指在申请日以前6个月内（A）
# A.科技成果鉴定中的论证
# B.他人未经申请人同意泄露其发明创造
# C.申请将发明创造内容写入专著，但尚未出版
# D.他人在申请人处看到与专利申请有关的次要附图
# 17、我国专利法及其实施细则规定，确定发明和实用新型专利权的保护范围的依据是（C）
# A.说明书 B.请求书 C.权利要求书 D.附图
# 18、在中国，实用新型和外观设计专利申请（B）
# A.须经过实质审查后授权 B.经初审合格后即授权
# C.递交申请后即可授权D.经过形式审查和实质审查后才可授权
# 19、两个以上的申请人分别就相同内容的发明创造向国务院专利行政部门提出申请，应该将专利权授予（B）
# A.同时申请的两个人B.先申请人 C.先使用人 D.发明人
# 20、我国专利申请原则不采用（B）
# A.书面原则 B.先发明原则 C.先申请原则 D.单一性原则
# 21、下列发明中，能授予专利权的是（C）
# A. 疾病的诊断和治疗方法
# B. 动物和植物品种
# C. 动物与植物品种产生方法
# D. 用原子核变换方法获得的物质
# 22、专利复审委员会宣告无效的发明专利权视为（A）
# A. 自始即不存在
# B. 自宣告无效日起即不存在
# C. 自申请宣告无效日起即不存在
# D. 自发明专利申请公布日起即不存在
# 23、下列各项中，依法可以申请专利的是（B）
# A.变魔术的方法 B.一种菜肴的烹饪方法 C.高血压针灸疗法 D.西红柿新品种
# 24、甲公司委托乙公司开发一种浓缩茶汁的技术秘密成果，未约定使用权、转让去权以及利益分配办法。甲公司按约定脂肪粒研究开发费用。乙公司按约定时间开发吃该技术秘密成果后，在没有向甲公司交付之前，将其转让给丙公司，下列哪种说法是正确的（B）
# A .该技术秘密成果的使用权只能属于甲公司
# B .该技术秘密成果的转让权只能属于乙公司
# C .甲公司和乙公司均有该技术秘密成果的使用权和转让权
# D .乙公司与丙公司的转让合同无效
# 25、甲公司研制开发出一项汽车刹车装置的专利技术，委托一公司生产该刹车装置的专用零部件。乙公司在生产过程中擅自将该种零部件出售给丙公司，致使丙公司很快也开发出同种刹车装置并投入生产。下列哪种说法是错误的（A）
# A．乙公司的行为构成违约行为
# B．丙公司侵犯了甲公司的专利权
# C．在甲公司提起的专利侵权诉讼中
# 26、以我国甲公司在中国和日本均注册了商标W,而日本的乙企业在其本国在同种商品上使用了W商标，乙企业侵犯了我国甲公司（B）
# A.在中国的商标权 B.在日本的商标权
# C.在中国和日本的商标权 D.在亚洲地区的商标权
# 27、某公司申请一商标注册，在商标局初步审定公告后，该公司即开始使用，并标注了注册商标的标记，该公司的行为属于（A）
# A.冒充注册商标B.合理使用 C.合法使用 D.假冒他人注册商标
# 28、甲公司于2000年3月为其生产的酸奶注册了“乐乐”商标，该商标经过长期使用，在公众中享有较高声誉。2004年8月，同一地域销售牛奶的乙公司将“乐乐”登记为商号并突出宣传使用，容易使公众产生误认。下列哪种说法是正确的（C）
# A. 乙公司的行为必须实际造成消费者误认，才是侵犯甲公司的商标权
# B. 即使“乐乐”不属于驰名商标，乙公司的行为也侵犯了甲公司的商标权
# C. 甲公司可以直接向法院起诉要求撤销该商号登记
# D. 乙公司的商号已经合法登记，应受
# 29、下列关于商标专用权取得的原则，符合我国商标法的规定的是（C）
# A. 登记原则B. 登记并公告原则C. 注册原则D.使用原则
# 30、根据我国商标法的规定，下列哪些商标可以作为商标使用（B）
# A. WHO B. WCTP C.UN D. WIPO
# 二、判断题（1’X9）
# 1、计算机软件著作权的保护期为50年。（正确）
# 2、剽窃他人作品的行为，只可构成民事侵权，不可能构成犯罪。（正确）
# 3、在我国，外观设计获得专利权的实质要件为新颖性、创造性、实用性。（错误）
# 4、我国专利法规定，申请人自发明或者实用新型在外国第一次提出专利申请之日起12个月内，又在中国就相同主题提出专利申请的，按有关国际条约，可享有优先权。（正确）
# 5、第三人使用演绎作品，须同时取得演绎作品作者和原作作者的同意。（正确）
# 6、变魔术的方法依法可以申请方法专利。（错误）
# 7、对未注册商标，我国商标法明令禁止使用。（错误）
# 8、已经许可他人使用的商标，商标权人在转让时，可不必经许可人同意，但须通知被许可人。（错误）
# 9、一项产品发明专利申请文件经初审合格由专利行政部门公布后，就会产生专利申请人可以禁止改进该技术的后果。（正确）
# 以上就是小编为大家整理有关于精选知识产权知识竞赛试题题库及答案的相关内容，如果您想要了解更多信息，可持续关注我们。
# 精选知识产权知识竞赛试题题库及答案.doc            将本文的Word文档下载到电脑，方便收藏和打印            推荐度：                                                  mtw(\’banner-2pic\’)
# 本文来自网络，不代表爱作业立场，如若转载，请注明出处：https://www.aizuoye.com/a809712.html
# 俗语云：千里之堤毁于蚁穴。造成重大事故的原因，往往都是人们漠视违章引起的，可以说违章是事故的孪生兄弟。如果真正从源头上查找原因，我们就会发现，造成违章的主要是人为的因素在作怪。下面…
# 2023科普知识竞赛题库及答案(100题) 1、“牛郎织女”的故事是众口皆碑的神话传说,那你知道牛郎星是属于什么星座()? A、天琴座 B、天鹰座 C、金牛…
# 2023消毒供应知识竞赛题库及答案（100题) 1、湿热消毒应监测、记录每次的()()或()、应()检测清洗消毒器的温度、时间等主要性能参数。 A、消毒的温度 B、时间 C、A0值…
# 2023职业教育法知识竞赛题库及答案(250题) 1.职业教育实行(),分级管理、地方为主、行业指导、校企合作、社会参与。 A、政府主导 B、政府主管 C、政府统筹 D、政府协调 …
# 2023职教知识竞赛题库及答案(100题) 1.为了推动(),提高劳动者素质和技术技能水平,促进就业创业,建设教育强国、人力资源强国和技能型社会,推进社会主义现代化建设,根据宪法,…
# 《中华人民共和国民法典》审议通过3周年、《中华人民共和国乡村振兴促进法》公布实施两周年之际，“美好生活·民法典相伴”全国“民法典进…
# 在学习贯彻习近平新时代中国特色社会主义思想主题教育工作会议上，习主席明确提出“学思想、强党性、重实践、建新功”的总要求，为深入开展主题教育提供了重要遵循。我…
# 趣味知识竞赛习题试题含答案.doc 将本文的Word文档下载到电脑，方便收藏和打印 推荐度： mtw(\’banner-2pic\’)
# 六年级阅读知识竞赛试题及答案.doc 将本文的Word文档下载到电脑，方便收藏和打印 推荐度： mtw(\’banner-2pic\’)
# 一个人只要有梦想，生命就有了依托；一个人只有不懈地追逐着梦想，活着才觉得意义深远，趣味无穷，也才能将生命的潜能发挥到极致。下面是小编给大家分享的一些有关于安全生产知识竞赛题库及参考…
# Copyright © 2022 Www.Aizuoye.COM Rights Reserved.内容&广告合作: ad©aizuoye.com(© → @)
# 苏ICP备15020386号-25

# %%
#Extract question and answer
tf_question = re.findall(r"\d+、(.*?（ ）)",body,re.S)
#Extract question
mul_choice_tf= re.sub(r"知识产权是指智力创造成果(.|\n)*?一、单选题（1’X30）|以上就是小编(.|\n)*?-25","",body)
mul_choice_tf =  re.sub(r"(（).*?(）)",r"\1（\2）",mul_choice_tf).replace("（（））","（）")
mul_choice_tf_q = re.findall(r"\d+、(.*?)(?=\d+、)",mul_choice_tf,re.S)
#Combine all questions extracted from body text
total_question = []
for i in tf_question:
    total_question.append(i)
for j in mul_choice_tf_q:
    total_question.append(j)
#Extract answer
ans_body = re.sub(r"一、单选题（1’X30）|二、判断题.*?\s+","",body)
answer_1 = re.findall(r"\d+、.*?（ ）(.*?)(?=\d+、)",ans_body,re.S)
answer_2 = re.findall(r"\d+、.*?（(\S+)）",ans_body,re.S)
answer_2.pop()
answer_total = []
for i in answer_1:
    answer_total.append(i)
for j in answer_2:
    answer_total.append(j)

# %%
with open("精选知识产权知识竞赛试题题库及答案.json","w",encoding='utf-8') as f8:
    for i in range(0,len(total_question)):
        q,a = total_question[i],answer_total[i]
        d = {"question":q,"answer":a}
        f8.write(json.dumps(d,ensure_ascii=False)+"\n")

# %% [markdown]
# # 知识竞赛题库( Knowledge Competition Question Bank)

# %%
df_htext = pd.read_excel('知识竞赛题库.xlsx')
fw = open("知识竞赛题库.json","w",encoding='utf-8') 
for i in range(len(df_htext)):
    d = df_htext.iloc[i]
    URL = d[0] 
    question = d[1]
    answer = d[2]
    dw = {}
    dw["URL"] = URL
    dw["question"] = question
    dw["answer"] = answer
    fw.write(json.dumps(dw,ensure_ascii=False)+"\n")
fw.close()

# %% [markdown]
# # 知识竞赛题库( Knowledge Competition Question Bank)-cleaning

# %%
import json
import pandas as pd
dsd = open("知识竞赛题库.json",'r',encoding='utf-8').readlines()
f9 = open("知识竞赛库_clean.json","w",encoding='utf-8')
for line in dsd:
    item = json.loads(line)
    if 'question' in item:
        item['question']=item['question'].replace('所属题库：知识产权\t\t\t   \n\t\t\t   \n\t\t\t   \n\t\t\t   【单选】\n        \t\t\t\t\t   ',"")
        item['question']=item['question'].replace('\n\t\t\t\t',"  ")
        item['question']=item['question'].replace('\n\t\t\t   \t\n\t\t\t   \n\t\t\t   \t',"")
        item['question']=item['question'].replace('            \t \n            \t ',"")
        f9.write(json.dumps(item,ensure_ascii=False)+"\n")
    print(item)
f9.close()
# Out:
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '知识产权一般包括( )两部分。A、著作权,工业产权  B、著作权,专利权  C、著作权,商标权', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '《中华人民共和国专利法》于( )年3月12日通过,()年9月4日第一次修订,()年8月25日第二次修订。A、1984、1992、2000  B、1983、1993、1999  C、1984、1993、2000', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '世界贸易组织《与贸易有关的知识产权协定》( )是迄今为止最具综合性的知识产权多边协议,其中规定了()的知识产权。A、集成电路布图设计  B、实用新型  C、植物新品种', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '下面哪一项不属于由 TRIPS协定所规定的基本原则( )。A、国民待遇原则  B、最惠国待遇原则  C、公共健康原则', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国于( )成为世界知识产权组织WIPO)的正式成员国。A、29375  B、29740  C、31125', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '以下知识产权国际公约中,最早订立的是( )A、《保护工业产权巴黎公约》  B、《伯尔尼保护文学和艺术作品公约》  C、《世界版权公约》', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在下列知识产权国际公约中,我国尚未加入的有( )。A、《保护表演者,录音制作者和广播组织的国际公约》(罗马公约)  B、《世界版权公约》  C、《国际植物新品种保护公约》', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在商标方面的国际公约中,我国未加入的是( )。A、《商标国际注册马德里协定》  B、《商标国际注册马德里协定有关议定书》  C、《商标法律条约》', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '世界知识产权组织于1974年成为联合国组织系统的一个专门机构,其总部位于( )A、瑞士日内瓦  B、瑞士洛桑  C、美国纽约', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '据世界知识产权组织统计,专利文献记载了人类( )以上的新技术信息。A、0.9  B、0.6  C、科技局,专利商标局,特许厅', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '英国1624年制定的( )被称为”专利法之母”。A、专利法  B、垄断法  C、反托拉斯法', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '《保护工业产权巴黎公约》规定的”专利与我国专利法规定的专利是否外延相同( )。A、完全相同  B、前者大于后者  C、后者大于前者', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '甲比乙早一周完成了一个相同的发明,但乙比甲早一天提出了专利申请,若此发明符合授予专利的条件,请问应当将专利授予( )。A、甲  B、乙  C、甲,乙共有', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '根据我国专利法,职务发明创造的专利权应当属于( )。A、单位  B、发明人  C、单位与发明人共有', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '根据我国著作权法,职务作品的著作权一般情况下属于( )。A、单位  B、作者  C、单位与作者共有', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '产品发明专利和实用新型专利权人有权禁止他人未经其许可而为生产经营目的( )其专利产品。A、制造,使用,销售,进口  B、使用,许诺销售,销售,进口  C、制造,使用,许诺销售,销售,进口', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '外观设计的专利权人有权禁止他人未经其许可而为生产目的( )其外观设计专利产品。A、制造,销售,进口  B、制造,使用,销售  C、制造,使用,进口', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定的授予发明专利和实用新型专利的三性条件是指( )。A、新颖性,创造性和实用性  B、新颖性,创造性和显著性  C、新颖性,独创性和实用性', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在申请日以前6个月之内发生如下哪一种情形的,不丧失新颖性( )。A、在中国政府主办或者承认的国际展览会上首次展出的  B、在学术期刊上首次发表的  C、自己上传到互联网上的', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '根据我国专利法的规定,可以授予专利权的对象有( )。A、科学家发现了某种此前不为人知的物质  B、某人新创设了一种下棋方法  C、新的微生物品种', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在下列主题中,( )可获得外观设计专利的保护。A、饮料  B、饮料的配方  C、饮料的包装盒', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在发明或者实用新型专利申请文件中,用于说明专利保护范围的是( )。A、请求书  B、说明书  C、权利要求书', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '申请外观设计专利应当提交的文件是( )。A、请求书和图片或照片  B、说明书和图片或照片  C、权利要求书和图片或照片', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '所谓外国优先权是指在外国第一次提出专利或者商标注册申请之后又在中国就相同主题或者相同商品上的同一商标提出申请的,可以根据国际条约,双边协议或者互惠原则享有优先权,即以在外国的第一次申请作为在中国的申请日但享有优先权是受到时间限制的,根据我国专利法和著作权法的规定,该优先权期限分别是指( )。A、发明和实用新型是12个月,外观设计和商标是6个月  B、发明是12个月,实用新型,外观设计和商标是6个月  C、发明,实用新型和外观设计是12个月,商标是6个月', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定,发明专利申请经初步审查认为符合要求的,( )公布。A、必须自申请日起满18个月才能  B、自申请日起满18个月即行公布,但可应申请人请求早日  C、只能应申请人请求', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定必须进行实质审查的专利是( )。A、发明  B、发明和实用新型  C、发明,实用新型和外观设计', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定的专利权保护期限是( )。A、自申请日起发明专利20年,实用新型和外观设计专利10年  B、自生效日起发明专利15年,实用新型和外观设计专利10年  C、自公告日起发明专利20年,实用新型和外观设计专利10年', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '修订后的专利法规定,就下列哪些( )专利,当事人对于专利复审委员会的复审决定或者宣告专利无效的决定不服而可向法院起诉()。A、发明  B、发明和实用新型  C、发明,实用新型和外观设计', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在我国,当事人对于专利复审委员会的复审决定或者宣告专利无效的决定不服的,应当自收到通知之日起3个月内向( )起诉。A、北京市第一中级人民法院  B、北京市第二中级人民法院  C、北京市高级人民法院', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定,转让专利申请权或者专利权的,当事人应当订立书面合同,并向国务院专利行政部门登记,由该部门予以公告、专利申请权或者专利权的转让自( )之日起生效。A、合同订立  B、登记  C、公告', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '某人完成一项发明后,从其个人利益最大化的角度看,合理的做法是( )。A、马上去申请专利  B、马上在一份专业杂志上发表  C、权衡利弊,确定究竟采取专利保护还是保持为商业秘密', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '管理专利工作的部门在专利权人请求其处理侵犯专利权的行为时,可以( )。A、认定侵权行为成立,责令停止侵权行为并确定赔偿数额  B、认定侵权行为成立,责令停止侵权行为并就赔偿数额进行调解  C、认定侵权行为成立,责令停止侵权行为,不得就赔偿问题进行调解或确定赔偿数额', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '专利权人应当自被授予专利权的当年开始缴纳年费,年费的计算是( )。A、每年相同的  B、递增的  C、递减的', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '以下哪种行为侵犯了专利权( )。A、为实验目的而使用他人有关专利  B、甲购买乙的专利产品,而后出售给丙,获利甚丰  C、甲和乙各自完成了相同的产品发明,乙通过申请获得了专利,但甲随后也开始生产销售自己的发明产品', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '《专利合作条约》(PCT)所建立的国际体系,使得在一个专利局以一种语言提交的一项申请(国际申请)在申请人指定的 成员国都具有相同的效力,以达到简化,经济之目的、我国成为 正式成员国的时间是()。A、33970  B、34335  C、34700', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '根据我国法律,下列侵犯知识产权的行为中不可能构成犯罪的有( )。A、擅自实施他人专利  B、假冒他人商标  C、盗版他人作品', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '转让注册商标的,商标注册人对其在同一或者类似商品上注册的相同或者近似的商标,( )。A、应当一并转让  B、可以分别转让  C、应当给予强制许可', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在我国,知识产权民事纠纷案件一般应由( )管辖。A、基层人民法院  B、中级人民法院  C、高级人民法院', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '侵犯知识产权的诉讼时效为( ),自权利人或者利害关系人知道或者应当知道侵权行为之日起计算。A、1年  B、2年  C、4年', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在美国,当事人对于专利纠纷案件一审判决不服的,只能上诉到( )。A、联邦巡回上诉法院  B、美国最高法院  C、哥伦比亚特区法院', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '美国甲公司对其发明在美国拥有一项专利,但它从未在中国申请并获得过专利,则其能否在中国得到保护( )。A、在中国同样可以得到专利保护  B、尽管没有专利但在中国可以得到商业秘密保护  C、不能得到任何保护', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在我国,植物新品种权的保护期限是自( )起,藤本植物,林木,果树和观赏树木为20年,其他植物为15年。A、授权日  B、申请日  C、完成育种日', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '新的《海关知识产权保护条例》于( )开始实施。A、37956  B、37987  C、38047', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '两个以上的专利申请人分别、先后就同样的发明创造申请中国专利,专利权应授予( )。A、最先完成该发明创造的人  B、最先提出该专利申请的人  C、最先将该发明创造投入生产使用的人', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '被宣告无效的发明专利权,( )。A、自宣告该专利权无效之日起无效  B、自该专利申请之日起无效  C、自授予该专利权之日起无效。', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '一件发明或者实用新型专利申请应当限于( )发明或实用新型。A、一项  B、二项  C、二项以上', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在我国,H公司在五年前获得了“一种新型控制器”产品的发明专利权,下列( )的行为侵犯了H公司的专利权?A、F商厦每年从H公司购买大量该专利产品后又将这些专利产品对外销售  B、在H公司专利申请日前已经每年生产1000件相同产品的G厂,今年又增加生产该产品3000件,其今年总产量达到4000件  C、J研究所为科学研究和实验目的而使用了二件H公司的该发明专利产品', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '上海东方通信高科技有限公司在上海向国家知识产权局上海专利代办处提交了三份专利申请,其专利申请的受理与审查单位是( )。A、国务院专利行政部门  B、上海市知识产权局  C、国家知识产权局上海专利代办处', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国发明专利权、实用新型专利权和外观设计专利权的保护期限分别是( )年。A、20年、10年、8年  B、20年、10年、10年  C、15年、8年、8年', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '江南化工研究所张某主要利用本所的设备、资金和技术资料完成的一项发明创造,该研究所与张某之间没有就该项发明创造的专利申请权达成过任何协议,该发明专利的申请权依法应属于( )。A、张某  B、江南化工研究所  C、江南化工研究所与张某共有', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '某研究所拥有以下成果,可以申请专利权的有( )。A、一种颈椎病治疗仪  B、一种颈椎病治疗方法  C、该治疗仪的客户销售名单', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '专利权人对国务院专利行政部门驳回申请的决定不服的,可以自收到申请之日起( ),向专利复审委员会请求复审。A、3个月内  B、6个月内  C、12个月内', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '依我国商标法的规定,商标专用权授予符合法定条件的( )。A、商标设计人  B、商标使用人  C、商标申请人', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '商品的通用名称,经使用取得显著特征并便于识别的,即产生第二含义的,( )。A、可以作为商标注册和使用  B、不能作为商标使用,也不能作为商标注册  C、可以作为商标注册,但不可以作为商标使用', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国商标法规定商标构成的要素有( )。A、文字、图形、字母、数字、气味、三维标志  B、文字、图形、字母、数字、音乐、三维标志  C、文字、图形、字母、数字、颜色组合、三维标志', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '转让注册商标的,受让人享有注册商标专用权的起始日为( )。A、转让协议公告之日  B、转让合同签订日  C、转让合同生效日', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '植物新品种,是指经过人工培育的或者对发现的野生植物加以开发,具备新颖性、( )、一致性和稳定性并有适当命名的植物品种。A、独创性  B、时间性  C、特异性', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '世界知识产权日是( )。A、44287  B、44312  C、44324', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '知识产权又被称为智慧财产权,它主要包括( )三大部分。A、专利、商标、集成电路设计  B、专利、商标、著作权  C、著作权、商标权、商业秘密', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '哪个国家率先提出“知识产权战略立国”?( )A、美国  B、日本  C、英国', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '“专利制度是给天才之火浇上利益之油”这句名言出自( )A、丘吉尔  B、林肯  C、约翰逊', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '国务院吴仪副总理在( )提出我国要实施知识产权战略。A、2004年  B、2003年  C、2002年', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '世界上最早建立专利制度的国家是( )。A、英国  B、法国  C、威尼斯共和国', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '专利法的本质是( )。A、对发明创造专利权提供法律保护  B、发明创造的推广应用  C、鼓励成名成家', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '新修改的专利法突出强调了专利立法要为( )服务。A、技术跨越发展  B、科技进步与创新  C、引进技术', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国的专利申请由下列哪一机构批准?( )A、省专利管理部门  B、市专利管理部门  C、国家知识产权局专利局', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '某单位职工拟就一项非职务发明申请专利( )。A、须经单位领导同意  B、可以直接向国家知识产权局专利局递交申请  C、须经专家鉴定或有关部门审批', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定,两个或两个以上的专利申请人就相同内容先后提出申请,谁有权获得专利权( )。A、第一个完成发明创造的人  B、第一个提出专利申请的人  C、两人共同拥有', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '如果专利申请文件是邮寄的,申请日应当如何确定?( )A、以专利局收到日为申请日  B、以寄出的邮戳日为申请日  C、以寄达的邮戳日为申请日', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '对于符合专利法规定的专利申请,由国务院专利行政部门颁发( )。A、发明证书  B、专利证书  C、科技成果证书', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国发明专利权的保护期限为几年?( )A、10年  B、15年  C、20年', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国实用新型和外观设计专利权的保护期限为几年?( )A、10年  B、15年  C、20年', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '发明或实用新型专利权的保护范围以哪一项内容为准( )A、说明书  B、权利要求书  C、请求书', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '专利申请优先权是指申请人就同一发明创造第一次提出专利申请后,在规定的期限内又向他国提出申请的,可享有第一次提出的( )的权利。A、申请日  B、授权日  C、发明日', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '美国甲公司对其发明在美国拥有一项专利,但它从未在中国申请并获得过专利,则其能否在中国得到保护?( )。A、在中国同样可以得到专利保护  B、尽管没有专利,但在中国可以得到商业秘底  C、不能得到任何保护', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定发明专利权的生效日期是( )A、发给专利证书之日  B、专利局作出授予专利权决定之日  C、专利权公告之日', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '王先生认为某项专利的授予不符合《中华人民共和国专利法》的有关规定,他应该请求什么机关宣告该专利权无效?( )。A、专利复审委员会  B、市知识产权局  C、中级人民法院', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '某公司在自己生产的产品上随意打上一个不存在的专利号,属于( )。A、假冒专利行为  B、冒充专利行为  C、盗窃专利行为', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '授予专利权的发明和实用新型应当具备( )条件A、新颖性、创造性、实用性  B、新颖性、突破性、实用性  C、新颖性、创造性、突破性', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在我国审批专利的原则是?( )。A、先申请原则  B、先发明原则  C、先使用原则', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '申请专利时申请人应当向专利局提交申请文件一式( )。A、两份  B、三份  C、一份', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '甲研究所接受乙企业的委托完成一项有关污水处理装置发明创造。在双方事前无协议约定的情况下,则专利申请权应属于( )。A、甲研究所  B、乙企业  C、应属于甲乙共有', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '甲公司指派其研究人员乙和丙共同研究开发一项技术,该技术开发完成后,甲公司决定就该项技术申请专利。在填写专利申请文件时“发明人”一栏应当填写( )。A、甲公司的名称  B、乙或者丙的姓名  C、乙和丙的姓名', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '某人完成一项发明后,如果该发明容易为他人所仿造剽窃,那么请问从其个人利益最大化的角度看,合理的做法是( )。A、马上去申请专利  B、马上在一份专业杂志上发表  C、将其保持为商业保密', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '专利申请权和专利权转让时,必须办理的手续是什么?( )A、订立书面合同  B、经市知识产权局批准  C、订立书面合同并经国务院专利行政部门登记', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '国务院专利行政部门收到发明专利申请后,经初步审查认为符合本法要求的,自申请日起满多少个月,即行公布?( )A、18个月  B、12个月  C、6个月', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '发明专利申请自申请日起多少年内,专利局可以根据申请人随时提出的请求,对其进行实质审查?( )A、1年  B、2年  C、3年', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '专利申请被驳回,申请人不服,三个月内可以向哪个机构请求复审?( )。A、专利局专利复审委员会  B、人民法院  C、地方知识产权局', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '中学生李某制作了一项小发明,一般而言,他可在( )申请专利A、18岁以后  B、小发明制作完成  C、学校同意以后', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在我国就新型电视机的制造方法可以提出( )。A、发明、外观设计专利申请  B、发明、实用新型、外观设计专利申请  C、发明专利申请,不能申请实用新型或外观设计专利', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '我国专利法规定,外观设计专利权的保护范围( )。A、以外观设计专利产品为准  B、以图片和照片为准  C、以表示在图片或者照片中的该外观设计专利产品为准', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '甲、乙、丙三方合作开发并共同完成了一项发明创造,三方又未约定专利权归属的,当甲方不同意申请专利时,( )。A、乙方和丙方都可以单独申请专利  B、乙丙双方可以以甲、乙、丙三方的名义共同申请专利  C、乙方、丙方都不能申请专利', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '被宣告无效的发明专利权,( )。A、自宣告该专利权无效之日起无效  B、自该专利申请之日起无效  C、自授予该专利权之日起无效。', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '假冒他人专利,情节严重的,处多少年以下有期徒刑或拘役?( )A、1年  B、3年  C、5年', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '从2003年10月1日起,专利申请号由原有的8位数升至( )位数。A、13  B、12  C、10', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '发明专利申请公布后至专利权授予前使用这发明未支付适当使用费的,专利权人要求支付使用费的诉讼时效为( )。A、1年  B、2年  C、3年', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '对冒充专利行为,( )有权责令其改正并予公告。A、管理专利工作的部门  B、人民法院  C、工商行政管理部门', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '在中国,美国和日本受理专利申请的机构分别为()。A、知识产权局,专利商标局,特许厅  B、知识产权局,专利局,发明协会  C、科技局,专利商标局,特许厅', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '国务院专利行政部门发出授予专利权的通知后,申请人应当自收到通知之日起( )个月内办理缴纳专利第一次年费和登记费等手续。A、1  B、2  C、3', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '下列文件被认为是世界上第一部版权法的是( )。A、1709年英国的《安娜女王法》  B、1890年美国的《谢尔曼反不正当竞争法》  C、世贸组织的《知识产权协定》D、1900的《巴黎公约》', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '说知识产权是( ),比较全面。A、活着的人的智力成果  B、自然人的智力成果  C、自然人或法人的智力成果D、公民的智力成果', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '专利权的地域性是指在( )拥有法律保护。A、权利人所在的民族区域  B、申请地所在的国家或者地区  C、权利人所在国家的建交国家或地区D、权利人的国籍国或地区', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '下列选项,哪项中含有保护期限不受时间限制的知识产权?( )A、商标权  B、著作权  C、实用新型专利权D、发明专利权', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '狭义的知识产权包括( )。A、工业产权和版权  B、著作权和商标权  C、专利权和著作权D、邻接权和集成电路布图设计权', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '作者的传播权包括( )。A、放映权和展览权  B、人身权和财产权  C、排他权和独占权D、表演者权、录制者权广播组织权、出版者权', 'answer': '正确答案：D'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '以下属于知识产权范围的是( )。A、石子游戏规则  B、数学累加方法  C、作家头脑中的灵感D、舞蹈演员的表演', 'answer': '正确答案：D'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '以下属于知识产权性质范围的是( )。A、可触摸性  B、不可复制性  C、无形性D、永久性', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '工业产权中的创造性成果权包括( )。A、发明专利权、使用新型权、外观设计权  B、商标权、商号权  C、服务标记权、货源标记权、原产地名称权D、制止不正当竞争权', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '以下属于边缘保护对象的是( )。A、外观设计权  B、商标权  C、著作权D、专利权', 'answer': '正确答案：A'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '广义的版权分为( )。A、人身权和邻接权  B、作品的创作者权、作品的传播权  C、财产权和邻接权D、人身权和表演者权', 'answer': '正确答案：B'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '知识产权公约协议中,1994年4月15签署、1995年1月1日生效的是那一协议( )。A、尼泊尔公约  B、巴黎公约  C、与贸易有关的知识产权D、世界知识产权组织公约', 'answer': '正确答案：C'}
# {'URL': 'http://www.zhishijingsai.cn/zhishichanquan/', 'question': '以下不是我国民法通则中保护的知识产权形式的是( )。A、著作权、专利权  B、商标权、发明权  C、发现权及其他科技成果权D、制止不正当竞争权', 'answer': '正确答案：D'}

# %% [markdown]
# # 知识产权保护题库合集(Collection of Intellectual Property Protection Question Bank)2021-2023

# %%
books_2023=['2023年初级经济师知识产权考试题库：第四章-专利运用 - 上海经济师.html','2023年初级经济师知识产权考试题库：第六章-商标使用 - 上海经济师.html','2023年初级经济师知识产权考试题库：第五章-商标基础 - 上海经济师.html','2023年初级经济师知识产权考试题库：第二章、专利申请、授权与确权 - 上海经济师.html','2023年初级经济师知识产权考试题库：第七章-商标保护 - 上海经济师.html','2023年初级经济师知识产权考试题库：第一章-知识产权基础 - 上海经济师.html','2023年初级经济师知识产权考试题库： 第三章-专利保护 - 上海经济师.html']

# %%
f10 = open("知识产权保护题库合集2023.json","w",encoding='utf-8')
for i in books_2023:
    html = open(i,'r',encoding='utf8').read()
    file = bs(html,'html.parser')
    title = file.title.string.strip() if file.title else ''
    body = '\n'.join([p.get_text().strip() for p in file.find_all('p')])
    print(body)
    question = re.findall(r"\d+(.*?)(?=参考答案)",body,re.S)
    ans = re.findall(r"(参考答案.*?)(?=\d)",body,re.S)
    for i in range(0,len(question)):
        q,a = question[i],ans[i]
        d = {"question":q,"answer":a}
        f10.write(json.dumps(d,ensure_ascii=False)+"\n")
        print(d)
# Out:
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 第四章-专利运用
# 1关于专利实施的说法，错误的是（）。
# A.独占许可
# B.排他许可
# C.普通许可
# D.分许可
# 参考答案：D
# 参考解析：
# 专利实施通常有广义和狭义之分。狭义的专利实施是指制造、使用专利产品以及使用专利方法的行为。广义的专利实施是指制造、使用、许诺销售、销售、进口专利产品，或者使用专利方法以及使用、许诺销售、销售、进口依照该专利方法直接获得的产品的行为。专利实施可以采用多种形式，专利权人既可以自己实施，也可以许可他人实施。我国对专利实施采用的是广义的含义。
# 2（）可以用于分析研判重点技术。
# A.专利量逐年变化分析
# B.主题词频次排序
# C.专利分类号逐年变化分析
# D.技术主题词逐年变化分析
# 参考答案：B
# 参考解析：
# 主题词频次排序是通过对所采集的分析样本中技术主题词对应的专利数量或占总量的比例进行统计和频次排序，其中排名靠前、所占份额较大的技术主题词对应的技术内容为重点技术。
# 3专利权人虽然自身具备一定的实施专利技术的能力，但因规模相对较小，并不能充分实施其专利技术，可优先考虑（）。
# A.重点专利发明人分析
# B.共同申请人分析
# C.合作研发团队分析
# D.研发团队规模变化分析
# 参考答案：B
# 参考解析：
# 排他许可是指专利权人许可他人在合同约定的地域、期限及方式的范围内实施其专利技术，也可自行实施该专利技术，但不得再另外许可第三方实施该专利技术。实践中，采用这种许可方式的专利权人虽然自身具备一定的实施专利技术的能力，但因规模相对较小，并不能充分实施其专利技术。
#
# 您的现状是？
# 填写信息，获取结果
# 鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：
# 信息收集范围
# 我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：
# 1、您在使用我们服务时主动提供的信息
# (1)您在网站上报名填写的姓名、电话、住址、微信/QQ、备注等信息。
# (2)您通过电话咨询方式提供的姓名、电话、住址、微信/QQ、备注等信息。
# (3)您在使用网上咨询服务所提供的姓名、电话、住址、微信/QQ、备注等信息。
# (4)您参与我们线上活动时填写的调查问卷中可能包含您的姓名、电话、地址等信息。
# 我们的部分服务可能需要您提供特定的个人敏感信息来实现特定功能。
# 若您选择不提供该类信息，则可能无法正常使用服务中的特定功能，但不影响您使用服务中的其他功能。
# 若您主动提供您的个人敏感信息，即表示您同意我们按本政策所述目的和方式来处理您的个人敏感信息。
# 本次报名服务由上海经济师网提供，本站不承担由于内容的不一致性所引起的一切争议和法律责任，报名结果以最终报名系统所填写的信息为准。
# 信息使用用途
# 我们严格遵守法律法规的规定及与用户的约定，将收集的信息用于以下用途。若我们超出以下用途使用您的信息，我们将再次向您进行说明，并征得您的同意。
# 1、向您提供服务。
# 2、满足您的个性化需求。例如，技能提升规划、学历提升培训等。
# 3、项目开发和服务优化。例如，通过您的咨询问题及服务过程中您的建议等，优化我们的服务。
# 4、向您推荐您可能感兴趣的资讯等。
# 5、项目推荐。例如，我们会根据您的具体要求以及您所具备的条件向您推荐合适的项目。
# 为了让您有更好的体验、改善我们的服务或经您同意的其他用途，在符合相关法律法规的前提下，我们可能将通过某些服务所收集的信息用于我们的其他服务。例如，将您在使用我们某项服务时的信息，用于另一项服务中向您展示个性化的内容或广告、用于用户研究分析与统计等服务。
# 信息保护
# 我们仅在本《隐私政策》所述目的所必需的期间和法律法规要求的时限内保留您的个人信息。
# 本网站将对您所提供的资料进行严格的管理及保护，本网站将使用相应的技术，防止您的个人资料丢失、被盗用或遭篡改。
# 当政府机关依照法定程序要求本网站披露个人资料时，本网站将根据执法单位之要求或为公共安全之目的提供个人资料。在此情况下之任何披露，本网站均得免责。
# 由于您将用户密码告知他人或与他人共享注册帐户，由此导致的任何个人资料泄露。任何由于计算机问题、黑客政击、计算机病毒侵入或发作、因政府管制而造成的暂时性关闭等影响网络正常经营之不可抗力而造成的个人资料泄露、丢失、被盗用或被篡改情况时本网站亦毋需承担任何责任。
# 未成年人保护
# 本网站将建立和维持一合理的程序，以保护未成年人个人资料的保密性及安全性。本网站郑重声明：任何16岁以下的未成年人参加网上活动应事先得到家长或其法定监护人的可经查证的同意。若您是未成年人的监护人，当您对您所监护的未成年人的个人信息有相关疑问时，请通过与我们联系。
# 适用范围
# 我们的所有服务均适用本政策。但某些服务有其特定的隐私指引/声明，该特定隐私指引/声明更具体地说明我们在该服务中如何处理您的信息。如本政策与特定服务的隐私指引/声明有不一致之处，请以该特定隐私指引/声明为准。
# 您必须完全同意以上协议才能使用本网站的在线报名服务。
# (一）由于考试政策等各方面情况的不断调整与变化，本网站所提供的考试信息仅供参考，请以权威部门公布的正式信息为准。
# (二）本网站在文章内容来源出处标注为其他平台的稿件均为转载稿，免费转载出于非商业性学习目的，版权归原作者所有。如您对内容、版权等问题存在异议请于我们联系，我们会及时处理。
# 转载请注明：文章转载自https://www.shjjsw.net/
# 本文地址：https://www.shjjsw.net/show-1234-10124-1.html
# 2023年上海经济师便捷服务
# 经济师培训报名入口
# 备考资料领取入口
# 上海经济师报名指导入口
# 考生交流群
# 微信公众号
# 扫一扫加入微信交流群
# 扫一扫关注微信公众号
# {'question': '关于专利实施的说法，错误的是（）。\nA.独占许可\nB.排他许可\nC.普通许可\nD.分许可\n', 'answer': '参考答案：D\n参考解析：\n专利实施通常有广义和狭义之分。狭义的专利实施是指制造、使用专利产品以及使用专利方法的行为。广义的专利实施是指制造、使用、许诺销售、销售、进口专利产品，或者使用专利方法以及使用、许诺销售、销售、进口依照该专利方法直接获得的产品的行为。专利实施可以采用多种形式，专利权人既可以自己实施，也可以许可他人实施。我国对专利实施采用的是广义的含义。\n'}
# {'question': '（）可以用于分析研判重点技术。\nA.专利量逐年变化分析\nB.主题词频次排序\nC.专利分类号逐年变化分析\nD.技术主题词逐年变化分析\n', 'answer': '参考答案：B\n参考解析：\n主题词频次排序是通过对所采集的分析样本中技术主题词对应的专利数量或占总量的比例进行统计和频次排序，其中排名靠前、所占份额较大的技术主题词对应的技术内容为重点技术。\n'}
# {'question': '专利权人虽然自身具备一定的实施专利技术的能力，但因规模相对较小，并不能充分实施其专利技术，可优先考虑（）。\nA.重点专利发明人分析\nB.共同申请人分析\nC.合作研发团队分析\nD.研发团队规模变化分析\n', 'answer': '参考答案：B\n参考解析：\n排他许可是指专利权人许可他人在合同约定的地域、期限及方式的范围内实施其专利技术，也可自行实施该专利技术，但不得再另外许可第三方实施该专利技术。实践中，采用这种许可方式的专利权人虽然自身具备一定的实施专利技术的能力，但因规模相对较小，并不能充分实施其专利技术。\n\n您的现状是？\n填写信息，获取结果\n鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：\n信息收集范围\n我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：\n'}
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 第六章、商标使用
# 1 未注册商标冒充注册商标是一种欺骗相关公众的行为，扰乱了商标注册管理秩序，依法应（）。
# A.承担民事侵权责任
# B.承担刑事责任
# C.予以制止并给予行政处罚
# D.赔偿他人损失
# 参考答案：C
# 参考解析：
# 本题考察的是注册商标的不当使用。
# 未注册商标冒充注册商标是一种欺骗相关公众的行为，扰乱了商标注册管理秩序，依法应予以制止并给予行政处罚。本题为原文内容的考察，ABD选项均不符合题意。
# 故本题正确答案为C。
# 2 （）是指商标管理机关依法对商标印制行为进行监督和检查，并对非法印制商标标志的行为予以查处的活动的总称。
# A.商标使用管理
# B.商标印制管理
# C.商标广告管理
# D.商标申请管理
# 参考答案：B
# 参考解析：
# 本题考察的是商标的印制。
# 商标印制管理是指商标管理机关依法对商标印制行为进行监督和检查，并对非法印制商标标志的行为予以查处的活动的总称。ACD均为干扰项。故本题正确答案为B。
# 3（）是指商标注册人在约定的期间、地域和以约定的方式，许可他人使用其注册商标，并可自行使用该注册商标和许可他人使用其注册商标。
# A.普通许可
# B.排他许可
# C.独占许可
# D.再许可
# 参考答案：A
# 参考解析：
# 本题考察的是注册商标的使用许可。
# 商标使用许可的类型包含独占许可、排他许可和普通许可。普通许可，是指商标注册人在约定的期间、地域和以约定的方式，许可他人使用其注册商标，并可自行使用该注册商标和许可他人使用其注册商标。排他许可是指商标注册人将注册商标仅许可一个被许可人在约定的期间、地域内以约定的方式使用，商标注册人在约定范围内也可使用该注册商标，但不得另行许可他人在以约定许可人使用的范围内使用该注册商标。独占许可是商标注册人将注册商标仅许可一个被许可人在约定的期间、地域内以约定的方式使用，而许可人或第三人在上述约定范围不得使用该商标。
# 再许可不属于商标使用许可的类型，故D选项错误。普通许可、独占许可和排他许可的许可范围是不同的，根据题干可知为普通许可。故本题正确答案为A。
# 您的现状是？
# 填写信息，获取结果
# 鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：
# 信息收集范围
# 我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：
# 1、您在使用我们服务时主动提供的信息
# (1)您在网站上报名填写的姓名、电话、住址、微信/QQ、备注等信息。
# (2)您通过电话咨询方式提供的姓名、电话、住址、微信/QQ、备注等信息。
# (3)您在使用网上咨询服务所提供的姓名、电话、住址、微信/QQ、备注等信息。
# (4)您参与我们线上活动时填写的调查问卷中可能包含您的姓名、电话、地址等信息。
# 我们的部分服务可能需要您提供特定的个人敏感信息来实现特定功能。
# 若您选择不提供该类信息，则可能无法正常使用服务中的特定功能，但不影响您使用服务中的其他功能。
# 若您主动提供您的个人敏感信息，即表示您同意我们按本政策所述目的和方式来处理您的个人敏感信息。
# 本次报名服务由上海经济师网提供，本站不承担由于内容的不一致性所引起的一切争议和法律责任，报名结果以最终报名系统所填写的信息为准。
# 信息使用用途
# 我们严格遵守法律法规的规定及与用户的约定，将收集的信息用于以下用途。若我们超出以下用途使用您的信息，我们将再次向您进行说明，并征得您的同意。
# 1、向您提供服务。
# 2、满足您的个性化需求。例如，技能提升规划、学历提升培训等。
# 3、项目开发和服务优化。例如，通过您的咨询问题及服务过程中您的建议等，优化我们的服务。
# 4、向您推荐您可能感兴趣的资讯等。
# 5、项目推荐。例如，我们会根据您的具体要求以及您所具备的条件向您推荐合适的项目。
# 为了让您有更好的体验、改善我们的服务或经您同意的其他用途，在符合相关法律法规的前提下，我们可能将通过某些服务所收集的信息用于我们的其他服务。例如，将您在使用我们某项服务时的信息，用于另一项服务中向您展示个性化的内容或广告、用于用户研究分析与统计等服务。
# 信息保护
# 我们仅在本《隐私政策》所述目的所必需的期间和法律法规要求的时限内保留您的个人信息。
# 本网站将对您所提供的资料进行严格的管理及保护，本网站将使用相应的技术，防止您的个人资料丢失、被盗用或遭篡改。
# 当政府机关依照法定程序要求本网站披露个人资料时，本网站将根据执法单位之要求或为公共安全之目的提供个人资料。在此情况下之任何披露，本网站均得免责。
# 由于您将用户密码告知他人或与他人共享注册帐户，由此导致的任何个人资料泄露。任何由于计算机问题、黑客政击、计算机病毒侵入或发作、因政府管制而造成的暂时性关闭等影响网络正常经营之不可抗力而造成的个人资料泄露、丢失、被盗用或被篡改情况时本网站亦毋需承担任何责任。
# 未成年人保护
# 本网站将建立和维持一合理的程序，以保护未成年人个人资料的保密性及安全性。本网站郑重声明：任何16岁以下的未成年人参加网上活动应事先得到家长或其法定监护人的可经查证的同意。若您是未成年人的监护人，当您对您所监护的未成年人的个人信息有相关疑问时，请通过与我们联系。
# 适用范围
# 我们的所有服务均适用本政策。但某些服务有其特定的隐私指引/声明，该特定隐私指引/声明更具体地说明我们在该服务中如何处理您的信息。如本政策与特定服务的隐私指引/声明有不一致之处，请以该特定隐私指引/声明为准。
# 您必须完全同意以上协议才能使用本网站的在线报名服务。
# (一）由于考试政策等各方面情况的不断调整与变化，本网站所提供的考试信息仅供参考，请以权威部门公布的正式信息为准。
# (二）本网站在文章内容来源出处标注为其他平台的稿件均为转载稿，免费转载出于非商业性学习目的，版权归原作者所有。如您对内容、版权等问题存在异议请于我们联系，我们会及时处理。
# 转载请注明：文章转载自https://www.shjjsw.net/
# 本文地址：https://www.shjjsw.net/show-1234-10160-1.html
# 2023年上海经济师便捷服务
# 经济师培训报名入口
# 备考资料领取入口
# 上海经济师报名指导入口
# 考生交流群
# 微信公众号
# 扫一扫加入微信交流群
# 扫一扫关注微信公众号
# {'question': ' 未注册商标冒充注册商标是一种欺骗相关公众的行为，扰乱了商标注册管理秩序，依法应（）。\nA.承担民事侵权责任\nB.承担刑事责任\nC.予以制止并给予行政处罚\nD.赔偿他人损失\n', 'answer': '参考答案：C\n参考解析：\n本题考察的是注册商标的不当使用。\n未注册商标冒充注册商标是一种欺骗相关公众的行为，扰乱了商标注册管理秩序，依法应予以制止并给予行政处罚。本题为原文内容的考察，ABD选项均不符合题意。\n故本题正确答案为C。\n'}
# {'question': ' （）是指商标管理机关依法对商标印制行为进行监督和检查，并对非法印制商标标志的行为予以查处的活动的总称。\nA.商标使用管理\nB.商标印制管理\nC.商标广告管理\nD.商标申请管理\n', 'answer': '参考答案：B\n参考解析：\n本题考察的是商标的印制。\n商标印制管理是指商标管理机关依法对商标印制行为进行监督和检查，并对非法印制商标标志的行为予以查处的活动的总称。ACD均为干扰项。故本题正确答案为B。\n'}
# {'question': '（）是指商标注册人在约定的期间、地域和以约定的方式，许可他人使用其注册商标，并可自行使用该注册商标和许可他人使用其注册商标。\nA.普通许可\nB.排他许可\nC.独占许可\nD.再许可\n', 'answer': '参考答案：A\n参考解析：\n本题考察的是注册商标的使用许可。\n商标使用许可的类型包含独占许可、排他许可和普通许可。普通许可，是指商标注册人在约定的期间、地域和以约定的方式，许可他人使用其注册商标，并可自行使用该注册商标和许可他人使用其注册商标。排他许可是指商标注册人将注册商标仅许可一个被许可人在约定的期间、地域内以约定的方式使用，商标注册人在约定范围内也可使用该注册商标，但不得另行许可他人在以约定许可人使用的范围内使用该注册商标。独占许可是商标注册人将注册商标仅许可一个被许可人在约定的期间、地域内以约定的方式使用，而许可人或第三人在上述约定范围不得使用该商标。\n再许可不属于商标使用许可的类型，故D选项错误。普通许可、独占许可和排他许可的许可范围是不同的，根据题干可知为普通许可。故本题正确答案为A。\n您的现状是？\n填写信息，获取结果\n鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：\n信息收集范围\n我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：\n'}
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 第五章、商标基础
# 1、（）是商标注册主管机关对商标注册申请是否合乎商标法的规定所进行的检查、资料检索、分析对比、调查研究并决定给予初步审定或驳回申请等一系列活动。
# A.商标注册
# B.商标审查
# C.商标资料准备
# D.商标申请
# 参考答案：B
# 参考解析：
# 本题考查的是商标审查的概念。商标审查是指商标注册主管机关对商标注册申请是否合乎商标法的规定所进行的检查、资料检索、分析对比、调查研究并决定给予初步审定或驳回申请等一系列活动。故本题正确答案为B。
# 2下列关于申请马德里国际商标办理的说法，错误的是（）。
# A.商标图样3张，如是彩色商标，还需附彩色商标图样3张
# B.填写并加盖公章的中文国际注册申请书
# C.填写并加盖公章或签字的外文国际注册申请书
# D.委托商标代理机构办理的，还应提交商标代理委托书
# 参考答案：A
# 参考解析：
# BCD说法均为正确说法，A选项应该是，商标图样2章，如是彩色商标，还需附彩色商标图样2张，故本题正确答案为A。
# 3 截至2015年，纯“协定”缔约方（仅加入马德里协定缔约方）为1个，是（）。
# A.卢森堡
# B.荷兰
# C.阿尔及利亚
# D.丹麦
# 参考答案：C
# 参考解析：
# 截至2015年，纯“协定”缔约方（仅加入马德里协定缔约方）为1个，即阿尔及利亚，故本题正确答案为C。
#
# 您的现状是？
# 填写信息，获取结果
# 鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：
# 信息收集范围
# 我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：
# 1、您在使用我们服务时主动提供的信息
# (1)您在网站上报名填写的姓名、电话、住址、微信/QQ、备注等信息。
# (2)您通过电话咨询方式提供的姓名、电话、住址、微信/QQ、备注等信息。
# (3)您在使用网上咨询服务所提供的姓名、电话、住址、微信/QQ、备注等信息。
# (4)您参与我们线上活动时填写的调查问卷中可能包含您的姓名、电话、地址等信息。
# 我们的部分服务可能需要您提供特定的个人敏感信息来实现特定功能。
# 若您选择不提供该类信息，则可能无法正常使用服务中的特定功能，但不影响您使用服务中的其他功能。
# 若您主动提供您的个人敏感信息，即表示您同意我们按本政策所述目的和方式来处理您的个人敏感信息。
# 本次报名服务由上海经济师网提供，本站不承担由于内容的不一致性所引起的一切争议和法律责任，报名结果以最终报名系统所填写的信息为准。
# 信息使用用途
# 我们严格遵守法律法规的规定及与用户的约定，将收集的信息用于以下用途。若我们超出以下用途使用您的信息，我们将再次向您进行说明，并征得您的同意。
# 1、向您提供服务。
# 2、满足您的个性化需求。例如，技能提升规划、学历提升培训等。
# 3、项目开发和服务优化。例如，通过您的咨询问题及服务过程中您的建议等，优化我们的服务。
# 4、向您推荐您可能感兴趣的资讯等。
# 5、项目推荐。例如，我们会根据您的具体要求以及您所具备的条件向您推荐合适的项目。
# 为了让您有更好的体验、改善我们的服务或经您同意的其他用途，在符合相关法律法规的前提下，我们可能将通过某些服务所收集的信息用于我们的其他服务。例如，将您在使用我们某项服务时的信息，用于另一项服务中向您展示个性化的内容或广告、用于用户研究分析与统计等服务。
# 信息保护
# 我们仅在本《隐私政策》所述目的所必需的期间和法律法规要求的时限内保留您的个人信息。
# 本网站将对您所提供的资料进行严格的管理及保护，本网站将使用相应的技术，防止您的个人资料丢失、被盗用或遭篡改。
# 当政府机关依照法定程序要求本网站披露个人资料时，本网站将根据执法单位之要求或为公共安全之目的提供个人资料。在此情况下之任何披露，本网站均得免责。
# 由于您将用户密码告知他人或与他人共享注册帐户，由此导致的任何个人资料泄露。任何由于计算机问题、黑客政击、计算机病毒侵入或发作、因政府管制而造成的暂时性关闭等影响网络正常经营之不可抗力而造成的个人资料泄露、丢失、被盗用或被篡改情况时本网站亦毋需承担任何责任。
# 未成年人保护
# 本网站将建立和维持一合理的程序，以保护未成年人个人资料的保密性及安全性。本网站郑重声明：任何16岁以下的未成年人参加网上活动应事先得到家长或其法定监护人的可经查证的同意。若您是未成年人的监护人，当您对您所监护的未成年人的个人信息有相关疑问时，请通过与我们联系。
# 适用范围
# 我们的所有服务均适用本政策。但某些服务有其特定的隐私指引/声明，该特定隐私指引/声明更具体地说明我们在该服务中如何处理您的信息。如本政策与特定服务的隐私指引/声明有不一致之处，请以该特定隐私指引/声明为准。
# 您必须完全同意以上协议才能使用本网站的在线报名服务。
# (一）由于考试政策等各方面情况的不断调整与变化，本网站所提供的考试信息仅供参考，请以权威部门公布的正式信息为准。
# (二）本网站在文章内容来源出处标注为其他平台的稿件均为转载稿，免费转载出于非商业性学习目的，版权归原作者所有。如您对内容、版权等问题存在异议请于我们联系，我们会及时处理。
# 转载请注明：文章转载自https://www.shjjsw.net/
# 本文地址：https://www.shjjsw.net/show-1234-10159-1.html
# 2023年上海经济师便捷服务
# 经济师培训报名入口
# 备考资料领取入口
# 上海经济师报名指导入口
# 考生交流群
# 微信公众号
# 扫一扫加入微信交流群
# 扫一扫关注微信公众号
# {'question': '、（）是商标注册主管机关对商标注册申请是否合乎商标法的规定所进行的检查、资料检索、分析对比、调查研究并决定给予初步审定或驳回申请等一系列活动。\nA.商标注册\nB.商标审查\nC.商标资料准备\nD.商标申请\n', 'answer': '参考答案：B\n参考解析：\n本题考查的是商标审查的概念。商标审查是指商标注册主管机关对商标注册申请是否合乎商标法的规定所进行的检查、资料检索、分析对比、调查研究并决定给予初步审定或驳回申请等一系列活动。故本题正确答案为B。\n'}
# {'question': '下列关于申请马德里国际商标办理的说法，错误的是（）。\nA.商标图样3张，如是彩色商标，还需附彩色商标图样3张\nB.填写并加盖公章的中文国际注册申请书\nC.填写并加盖公章或签字的外文国际注册申请书\nD.委托商标代理机构办理的，还应提交商标代理委托书\n', 'answer': '参考答案：A\n参考解析：\nBCD说法均为正确说法，A选项应该是，商标图样'}
# {'question': '章，如是彩色商标，还需附彩色商标图样2张，故本题正确答案为A。\n3 截至2015年，纯“协定”缔约方（仅加入马德里协定缔约方）为1个，是（）。\nA.卢森堡\nB.荷兰\nC.阿尔及利亚\nD.丹麦\n', 'answer': '参考答案：C\n参考解析：\n截至'}
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 第二章、专利申请、授权与确权
# 1.小明拥有一项发明专利，关于该发明专利基本特点的说法，正确的是（）。
# A.小明的专利权是在经法定部门审查批准后授予的
# B.小明的专利权是在其发明后自动获得的
# C.专利授权后，如果有人认为小明的专利授权不当，请求人不可以启动专利无效宣告请求审查程序
# D.小明在申请该专利时不必公开专利申请的内容
# 参考答案：A
# 参考解析：
# 本题考察的是专利的基本特点。
# A正确：专利权是经国务院专利行政部门经过法定的审查程序后批准获得的。
# B错误：著作权是自作品完成之日自动产生的，小明的发明专利需要经过法定的审查程序后批准获得。
# C错误：专利授权后，如果有人认为专利授权不当，法律还设置有专门的确权机制，即由请求人启动的专门机构审查的专利无效宣告请求审查程序。
# D错误：专利权是无形财产权，专利权的行使以专利申请授权内容公开为必要条件。
# 故本题正确答案为A。
# 2.关于实用新型申请文件审查的说法，错误的是（）。
# A.在实用新型专利申请初步审查中，明显实质性缺陷的范围大于发明专利申请的初步审查
# B.审查保护客体问题、单一性问题、申请文件修改超范围
# C.审查新颖性、实用性问题、说明书是否清楚完整、权利要求是否清楚以及是否以说明书为依据
# D.依赖遗传资源完成的实用新型发明创造，申请人无法说明原始来源的，应当在申请文件中陈述理由
# 参考答案：D
# 参考解析：
# 就明显实质性缺陷范围而言，相比于发明专利申请初步审查，实用新型专利申请初步审查中唯一减少的一项是根据《专利法》第二十六条第五款的审查，这是因为实用新型专利保护客体不会包括遗传资源类申请，因而不需要审查该类问题。
# 3.依据《专利法》，经过初步审查后可以授予专利权的是（）。
# A.一种新型表面活性剂的方法发明
# B.一种汽车润滑剂的产品发明
# C.一种海浪型汽车门把手设计
# D.一种自带消毒杀菌系统的公共垃圾桶
# 参考答案：C
# 收起解析
# 编辑取消关联
# 参考解析：
# 本题考察的是专利法定义的发明创造。
# 发明需要经过初步审查和实质审查后方可授权，而实用新型和外观设计仅须经过初步审查后即可授予专利权。
# 一种新型表面活性剂的方法发明属于发明专利中的方法创新，故A选项错误。
# 一种汽车润滑剂的产品属于发明专利中的产品创新，故B选项错误。
# 一种自带消毒杀菌系统的公共垃圾桶属于对产品、方法或者其改进所提出的新的技术方案，应当是发明专利的范畴。故D选项错误。
# 而一种海浪型汽车门把手设计是结合色彩与形状、图案所作出的富有美感并适于工业应用的新设计，因此属于外观设计。故C选项正确。
# 故本题选择C选项。
# 您的现状是？
# 填写信息，获取结果
# 鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：
# 信息收集范围
# 我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：
# 1、您在使用我们服务时主动提供的信息
# (1)您在网站上报名填写的姓名、电话、住址、微信/QQ、备注等信息。
# (2)您通过电话咨询方式提供的姓名、电话、住址、微信/QQ、备注等信息。
# (3)您在使用网上咨询服务所提供的姓名、电话、住址、微信/QQ、备注等信息。
# (4)您参与我们线上活动时填写的调查问卷中可能包含您的姓名、电话、地址等信息。
# 我们的部分服务可能需要您提供特定的个人敏感信息来实现特定功能。
# 若您选择不提供该类信息，则可能无法正常使用服务中的特定功能，但不影响您使用服务中的其他功能。
# 若您主动提供您的个人敏感信息，即表示您同意我们按本政策所述目的和方式来处理您的个人敏感信息。
# 本次报名服务由上海经济师网提供，本站不承担由于内容的不一致性所引起的一切争议和法律责任，报名结果以最终报名系统所填写的信息为准。
# 信息使用用途
# 我们严格遵守法律法规的规定及与用户的约定，将收集的信息用于以下用途。若我们超出以下用途使用您的信息，我们将再次向您进行说明，并征得您的同意。
# 1、向您提供服务。
# 2、满足您的个性化需求。例如，技能提升规划、学历提升培训等。
# 3、项目开发和服务优化。例如，通过您的咨询问题及服务过程中您的建议等，优化我们的服务。
# 4、向您推荐您可能感兴趣的资讯等。
# 5、项目推荐。例如，我们会根据您的具体要求以及您所具备的条件向您推荐合适的项目。
# 为了让您有更好的体验、改善我们的服务或经您同意的其他用途，在符合相关法律法规的前提下，我们可能将通过某些服务所收集的信息用于我们的其他服务。例如，将您在使用我们某项服务时的信息，用于另一项服务中向您展示个性化的内容或广告、用于用户研究分析与统计等服务。
# 信息保护
# 我们仅在本《隐私政策》所述目的所必需的期间和法律法规要求的时限内保留您的个人信息。
# 本网站将对您所提供的资料进行严格的管理及保护，本网站将使用相应的技术，防止您的个人资料丢失、被盗用或遭篡改。
# 当政府机关依照法定程序要求本网站披露个人资料时，本网站将根据执法单位之要求或为公共安全之目的提供个人资料。在此情况下之任何披露，本网站均得免责。
# 由于您将用户密码告知他人或与他人共享注册帐户，由此导致的任何个人资料泄露。任何由于计算机问题、黑客政击、计算机病毒侵入或发作、因政府管制而造成的暂时性关闭等影响网络正常经营之不可抗力而造成的个人资料泄露、丢失、被盗用或被篡改情况时本网站亦毋需承担任何责任。
# 未成年人保护
# 本网站将建立和维持一合理的程序，以保护未成年人个人资料的保密性及安全性。本网站郑重声明：任何16岁以下的未成年人参加网上活动应事先得到家长或其法定监护人的可经查证的同意。若您是未成年人的监护人，当您对您所监护的未成年人的个人信息有相关疑问时，请通过与我们联系。
# 适用范围
# 我们的所有服务均适用本政策。但某些服务有其特定的隐私指引/声明，该特定隐私指引/声明更具体地说明我们在该服务中如何处理您的信息。如本政策与特定服务的隐私指引/声明有不一致之处，请以该特定隐私指引/声明为准。
# 您必须完全同意以上协议才能使用本网站的在线报名服务。
# (一）由于考试政策等各方面情况的不断调整与变化，本网站所提供的考试信息仅供参考，请以权威部门公布的正式信息为准。
# (二）本网站在文章内容来源出处标注为其他平台的稿件均为转载稿，免费转载出于非商业性学习目的，版权归原作者所有。如您对内容、版权等问题存在异议请于我们联系，我们会及时处理。
# 转载请注明：文章转载自https://www.shjjsw.net/
# 本文地址：https://www.shjjsw.net/show-1234-10122-1.html
# 2023年上海经济师便捷服务
# 经济师培训报名入口
# 备考资料领取入口
# 上海经济师报名指导入口
# 考生交流群
# 微信公众号
# 扫一扫加入微信交流群
# 扫一扫关注微信公众号
# {'question': '.小明拥有一项发明专利，关于该发明专利基本特点的说法，正确的是（）。\nA.小明的专利权是在经法定部门审查批准后授予的\nB.小明的专利权是在其发明后自动获得的\nC.专利授权后，如果有人认为小明的专利授权不当，请求人不可以启动专利无效宣告请求审查程序\nD.小明在申请该专利时不必公开专利申请的内容\n', 'answer': '参考答案：A\n参考解析：\n本题考察的是专利的基本特点。\nA正确：专利权是经国务院专利行政部门经过法定的审查程序后批准获得的。\nB错误：著作权是自作品完成之日自动产生的，小明的发明专利需要经过法定的审查程序后批准获得。\nC错误：专利授权后，如果有人认为专利授权不当，法律还设置有专门的确权机制，即由请求人启动的专门机构审查的专利无效宣告请求审查程序。\nD错误：专利权是无形财产权，专利权的行使以专利申请授权内容公开为必要条件。\n故本题正确答案为A。\n'}
# {'question': '.关于实用新型申请文件审查的说法，错误的是（）。\nA.在实用新型专利申请初步审查中，明显实质性缺陷的范围大于发明专利申请的初步审查\nB.审查保护客体问题、单一性问题、申请文件修改超范围\nC.审查新颖性、实用性问题、说明书是否清楚完整、权利要求是否清楚以及是否以说明书为依据\nD.依赖遗传资源完成的实用新型发明创造，申请人无法说明原始来源的，应当在申请文件中陈述理由\n', 'answer': '参考答案：D\n参考解析：\n就明显实质性缺陷范围而言，相比于发明专利申请初步审查，实用新型专利申请初步审查中唯一减少的一项是根据《专利法》第二十六条第五款的审查，这是因为实用新型专利保护客体不会包括遗传资源类申请，因而不需要审查该类问题。\n'}
# {'question': '.依据《专利法》，经过初步审查后可以授予专利权的是（）。\nA.一种新型表面活性剂的方法发明\nB.一种汽车润滑剂的产品发明\nC.一种海浪型汽车门把手设计\nD.一种自带消毒杀菌系统的公共垃圾桶\n', 'answer': '参考答案：C\n收起解析\n编辑取消关联\n参考解析：\n本题考察的是专利法定义的发明创造。\n发明需要经过初步审查和实质审查后方可授权，而实用新型和外观设计仅须经过初步审查后即可授予专利权。\n一种新型表面活性剂的方法发明属于发明专利中的方法创新，故A选项错误。\n一种汽车润滑剂的产品属于发明专利中的产品创新，故B选项错误。\n一种自带消毒杀菌系统的公共垃圾桶属于对产品、方法或者其改进所提出的新的技术方案，应当是发明专利的范畴。故D选项错误。\n而一种海浪型汽车门把手设计是结合色彩与形状、图案所作出的富有美感并适于工业应用的新设计，因此属于外观设计。故C选项正确。\n故本题选择C选项。\n您的现状是？\n填写信息，获取结果\n鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：\n信息收集范围\n我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：\n'}
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 第七章、商标保护
# （）是指使用他人注册商标中的文字或图形等要素，用以善意的描述自己商品或服务的特征、产地等情况的行为。
# A.说明性使用
# B.商业性使用
# C.描述性使用
# D.指示性使用
# 参考答案：C
# 参考解析：
# 本题考察的是注册商标专用权的权利限制。
# 描述性使用：使用他人注册商标中的文字或图形等要素，用以善意的描述自己商品或服务的特征、产地等情况的行为。
# 指示性使用：使用他人注册商标中的文字或图形等要素，用以说明自己提供的商品或服务能够与使用该商标的商品或服务配套，或者为了说明自己提供的商品或服务的功能、用途、原料、制作工艺或者服务对象等，并不会导致消费者对商品或者服务来源的混淆。故本题正确答案为C。
# 2（）是指使用他人注册商标中的文字或图形等要素，用以说明自己提供的商品或服务能够与使用该商标的商品或服务配套，或者为了说明自己提供的商品或服务的功能、用途、原料、制作工艺或者服务对象等，不会导致消费者对商品或者服务来源的混淆。
# A.指示性使用
# B.商业性使用
# C.描述性使用
# D.商标性使用
# 参考答案：A
# 参考解析：
# 本题考察的是注册商标专用权的权利限制。
# 指示性使用：使用他人注册商标中的文字或图形等要素，用以说明自己提供的商品或服务能够与使用该商标的商品或服务配套，或者为了说明自己提供的商品或服务的功能、用途、原料、制作工艺或者服务对象等，并不会导致消费者对商品或者服务来源的混淆。
# 描述性使用：使用他人注册商标中的文字或图形等要素，用以善意的描述自己商品或服务的特征、产地等情况的行为。C选项不符合题意，BD选项均为干扰项。故本题正确答案为A。
# 3（）是指将商标中发挥主要识别作用的显著识别部分抽出来进行重点比较和对照，这是由于消费者往往会依据商标中给人留下深刻印象的要素来区分商品。
# A.局部比对
# B.隔离比对
# C.要部比对
# D.整体比对
# 参考答案：C
# 参考解析：
# 本题考察的是商标相同与近似的判定。
# 要部比对，是指将商标中发挥主要识别作用的显著识别部分抽出来进行重点比较和对照，这是由于消费者往往会依据商标中给人留下深刻印象的要素来区分商品。C选项正确。
# 整体对比，是指将商标作为一个整体来进行观察，考虑商标的整体印象，而不是仅仅将商标的各个构成要素抽离出来分别进行对比。
# 隔离对比，是指将注册商标与涉嫌侵权的商标放置于不同的地点，在不同的时间进行观察比对，而不是把两个要比对的商标摆放在一起进行对比观察，模拟消费者凭借对商品的既有印象选购商品的真实场景。故本题正确答案为C。
#
# 您的现状是？
# 填写信息，获取结果
# 鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：
# 信息收集范围
# 我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：
# 1、您在使用我们服务时主动提供的信息
# (1)您在网站上报名填写的姓名、电话、住址、微信/QQ、备注等信息。
# (2)您通过电话咨询方式提供的姓名、电话、住址、微信/QQ、备注等信息。
# (3)您在使用网上咨询服务所提供的姓名、电话、住址、微信/QQ、备注等信息。
# (4)您参与我们线上活动时填写的调查问卷中可能包含您的姓名、电话、地址等信息。
# 我们的部分服务可能需要您提供特定的个人敏感信息来实现特定功能。
# 若您选择不提供该类信息，则可能无法正常使用服务中的特定功能，但不影响您使用服务中的其他功能。
# 若您主动提供您的个人敏感信息，即表示您同意我们按本政策所述目的和方式来处理您的个人敏感信息。
# 本次报名服务由上海经济师网提供，本站不承担由于内容的不一致性所引起的一切争议和法律责任，报名结果以最终报名系统所填写的信息为准。
# 信息使用用途
# 我们严格遵守法律法规的规定及与用户的约定，将收集的信息用于以下用途。若我们超出以下用途使用您的信息，我们将再次向您进行说明，并征得您的同意。
# 1、向您提供服务。
# 2、满足您的个性化需求。例如，技能提升规划、学历提升培训等。
# 3、项目开发和服务优化。例如，通过您的咨询问题及服务过程中您的建议等，优化我们的服务。
# 4、向您推荐您可能感兴趣的资讯等。
# 5、项目推荐。例如，我们会根据您的具体要求以及您所具备的条件向您推荐合适的项目。
# 为了让您有更好的体验、改善我们的服务或经您同意的其他用途，在符合相关法律法规的前提下，我们可能将通过某些服务所收集的信息用于我们的其他服务。例如，将您在使用我们某项服务时的信息，用于另一项服务中向您展示个性化的内容或广告、用于用户研究分析与统计等服务。
# 信息保护
# 我们仅在本《隐私政策》所述目的所必需的期间和法律法规要求的时限内保留您的个人信息。
# 本网站将对您所提供的资料进行严格的管理及保护，本网站将使用相应的技术，防止您的个人资料丢失、被盗用或遭篡改。
# 当政府机关依照法定程序要求本网站披露个人资料时，本网站将根据执法单位之要求或为公共安全之目的提供个人资料。在此情况下之任何披露，本网站均得免责。
# 由于您将用户密码告知他人或与他人共享注册帐户，由此导致的任何个人资料泄露。任何由于计算机问题、黑客政击、计算机病毒侵入或发作、因政府管制而造成的暂时性关闭等影响网络正常经营之不可抗力而造成的个人资料泄露、丢失、被盗用或被篡改情况时本网站亦毋需承担任何责任。
# 未成年人保护
# 本网站将建立和维持一合理的程序，以保护未成年人个人资料的保密性及安全性。本网站郑重声明：任何16岁以下的未成年人参加网上活动应事先得到家长或其法定监护人的可经查证的同意。若您是未成年人的监护人，当您对您所监护的未成年人的个人信息有相关疑问时，请通过与我们联系。
# 适用范围
# 我们的所有服务均适用本政策。但某些服务有其特定的隐私指引/声明，该特定隐私指引/声明更具体地说明我们在该服务中如何处理您的信息。如本政策与特定服务的隐私指引/声明有不一致之处，请以该特定隐私指引/声明为准。
# 您必须完全同意以上协议才能使用本网站的在线报名服务。
# (一）由于考试政策等各方面情况的不断调整与变化，本网站所提供的考试信息仅供参考，请以权威部门公布的正式信息为准。
# (二）本网站在文章内容来源出处标注为其他平台的稿件均为转载稿，免费转载出于非商业性学习目的，版权归原作者所有。如您对内容、版权等问题存在异议请于我们联系，我们会及时处理。
# 转载请注明：文章转载自https://www.shjjsw.net/
# 本文地址：https://www.shjjsw.net/show-1234-10161-1.html
# 2023年上海经济师便捷服务
# 经济师培训报名入口
# 备考资料领取入口
# 上海经济师报名指导入口
# 考生交流群
# 微信公众号
# 扫一扫加入微信交流群
# 扫一扫关注微信公众号
# {'question': '（）是指使用他人注册商标中的文字或图形等要素，用以说明自己提供的商品或服务能够与使用该商标的商品或服务配套，或者为了说明自己提供的商品或服务的功能、用途、原料、制作工艺或者服务对象等，不会导致消费者对商品或者服务来源的混淆。\nA.指示性使用\nB.商业性使用\nC.描述性使用\nD.商标性使用\n', 'answer': '参考答案：C\n参考解析：\n本题考察的是注册商标专用权的权利限制。\n描述性使用：使用他人注册商标中的文字或图形等要素，用以善意的描述自己商品或服务的特征、产地等情况的行为。\n指示性使用：使用他人注册商标中的文字或图形等要素，用以说明自己提供的商品或服务能够与使用该商标的商品或服务配套，或者为了说明自己提供的商品或服务的功能、用途、原料、制作工艺或者服务对象等，并不会导致消费者对商品或者服务来源的混淆。故本题正确答案为C。\n'}
# {'question': '（）是指将商标中发挥主要识别作用的显著识别部分抽出来进行重点比较和对照，这是由于消费者往往会依据商标中给人留下深刻印象的要素来区分商品。\nA.局部比对\nB.隔离比对\nC.要部比对\nD.整体比对\n', 'answer': '参考答案：A\n参考解析：\n本题考察的是注册商标专用权的权利限制。\n指示性使用：使用他人注册商标中的文字或图形等要素，用以说明自己提供的商品或服务能够与使用该商标的商品或服务配套，或者为了说明自己提供的商品或服务的功能、用途、原料、制作工艺或者服务对象等，并不会导致消费者对商品或者服务来源的混淆。\n描述性使用：使用他人注册商标中的文字或图形等要素，用以善意的描述自己商品或服务的特征、产地等情况的行为。C选项不符合题意，BD选项均为干扰项。故本题正确答案为A。\n'}
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 第一章、知识产权基础
# 1.知识产权民事保护的归责原则是（）。
# A.过错原则
# B.无过错责任原则
# C.过失原则
# D.过错责任原则为主导、无过错责任原则为补充
# 参考答案：D
# 收起解析
# 编辑取消关联
# 参考解析：
# 关于侵害知识产权的赔偿责任，据我国《中华人民共和国民法通则》第106条规定，我国民法据此确立了以过错责任原则为主导、无过错责任原则为补充的侵权归责原则。
# 2.知识产权公共服务的基础是（）。
# A.咨询服务
# B.信息服务
# C.展示交易服务
# D.维权援助服务
# 参考答案：B
# 参考解析：
# 从服务的功能看，知识产权公共服务可分为申请代理援助服务、咨询服务、信息服务、展示交易服务、维权援助服务、融资与产业化服务等，其中，信息服务是所有相关服务的共同基础。
# 3.企业运行知识产权管理体系时间须达到（）个月以上才可以申请外部审核进行认证。
# A.2
# B.3
# C.4
# D.6
# 参考答案：B
# 参考解析：
# 企业运行知识产权管理体系时间须达到3个月以上才可以申请外部审核进行认证。
# 您的现状是？
# 填写信息，获取结果
# 鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：
# 信息收集范围
# 我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：
# 1、您在使用我们服务时主动提供的信息
# (1)您在网站上报名填写的姓名、电话、住址、微信/QQ、备注等信息。
# (2)您通过电话咨询方式提供的姓名、电话、住址、微信/QQ、备注等信息。
# (3)您在使用网上咨询服务所提供的姓名、电话、住址、微信/QQ、备注等信息。
# (4)您参与我们线上活动时填写的调查问卷中可能包含您的姓名、电话、地址等信息。
# 我们的部分服务可能需要您提供特定的个人敏感信息来实现特定功能。
# 若您选择不提供该类信息，则可能无法正常使用服务中的特定功能，但不影响您使用服务中的其他功能。
# 若您主动提供您的个人敏感信息，即表示您同意我们按本政策所述目的和方式来处理您的个人敏感信息。
# 本次报名服务由上海经济师网提供，本站不承担由于内容的不一致性所引起的一切争议和法律责任，报名结果以最终报名系统所填写的信息为准。
# 信息使用用途
# 我们严格遵守法律法规的规定及与用户的约定，将收集的信息用于以下用途。若我们超出以下用途使用您的信息，我们将再次向您进行说明，并征得您的同意。
# 1、向您提供服务。
# 2、满足您的个性化需求。例如，技能提升规划、学历提升培训等。
# 3、项目开发和服务优化。例如，通过您的咨询问题及服务过程中您的建议等，优化我们的服务。
# 4、向您推荐您可能感兴趣的资讯等。
# 5、项目推荐。例如，我们会根据您的具体要求以及您所具备的条件向您推荐合适的项目。
# 为了让您有更好的体验、改善我们的服务或经您同意的其他用途，在符合相关法律法规的前提下，我们可能将通过某些服务所收集的信息用于我们的其他服务。例如，将您在使用我们某项服务时的信息，用于另一项服务中向您展示个性化的内容或广告、用于用户研究分析与统计等服务。
# 信息保护
# 我们仅在本《隐私政策》所述目的所必需的期间和法律法规要求的时限内保留您的个人信息。
# 本网站将对您所提供的资料进行严格的管理及保护，本网站将使用相应的技术，防止您的个人资料丢失、被盗用或遭篡改。
# 当政府机关依照法定程序要求本网站披露个人资料时，本网站将根据执法单位之要求或为公共安全之目的提供个人资料。在此情况下之任何披露，本网站均得免责。
# 由于您将用户密码告知他人或与他人共享注册帐户，由此导致的任何个人资料泄露。任何由于计算机问题、黑客政击、计算机病毒侵入或发作、因政府管制而造成的暂时性关闭等影响网络正常经营之不可抗力而造成的个人资料泄露、丢失、被盗用或被篡改情况时本网站亦毋需承担任何责任。
# 未成年人保护
# 本网站将建立和维持一合理的程序，以保护未成年人个人资料的保密性及安全性。本网站郑重声明：任何16岁以下的未成年人参加网上活动应事先得到家长或其法定监护人的可经查证的同意。若您是未成年人的监护人，当您对您所监护的未成年人的个人信息有相关疑问时，请通过与我们联系。
# 适用范围
# 我们的所有服务均适用本政策。但某些服务有其特定的隐私指引/声明，该特定隐私指引/声明更具体地说明我们在该服务中如何处理您的信息。如本政策与特定服务的隐私指引/声明有不一致之处，请以该特定隐私指引/声明为准。
# 您必须完全同意以上协议才能使用本网站的在线报名服务。
# (一）由于考试政策等各方面情况的不断调整与变化，本网站所提供的考试信息仅供参考，请以权威部门公布的正式信息为准。
# (二）本网站在文章内容来源出处标注为其他平台的稿件均为转载稿，免费转载出于非商业性学习目的，版权归原作者所有。如您对内容、版权等问题存在异议请于我们联系，我们会及时处理。
# 转载请注明：文章转载自https://www.shjjsw.net/
# 本文地址：https://www.shjjsw.net/show-1234-10121-1.html
# 2023年上海经济师便捷服务
# 经济师培训报名入口
# 备考资料领取入口
# 上海经济师报名指导入口
# 考生交流群
# 微信公众号
# 扫一扫加入微信交流群
# 扫一扫关注微信公众号
# {'question': '.知识产权民事保护的归责原则是（）。\nA.过错原则\nB.无过错责任原则\nC.过失原则\nD.过错责任原则为主导、无过错责任原则为补充\n', 'answer': '参考答案：D\n收起解析\n编辑取消关联\n参考解析：\n关于侵害知识产权的赔偿责任，据我国《中华人民共和国民法通则》第'}
# {'question': '条规定，我国民法据此确立了以过错责任原则为主导、无过错责任原则为补充的侵权归责原则。\n2.知识产权公共服务的基础是（）。\nA.咨询服务\nB.信息服务\nC.展示交易服务\nD.维权援助服务\n', 'answer': '参考答案：B\n参考解析：\n从服务的功能看，知识产权公共服务可分为申请代理援助服务、咨询服务、信息服务、展示交易服务、维权援助服务、融资与产业化服务等，其中，信息服务是所有相关服务的共同基础。\n'}
# {'question': '.企业运行知识产权管理体系时间须达到（）个月以上才可以申请外部审核进行认证。\nA.2\nB.3\nC.4\nD.6\n', 'answer': '参考答案：B\n参考解析：\n企业运行知识产权管理体系时间须达到'}
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 第三章-专利保护
# 1.关于专利侵权构成要件的说法，错误的是（）。
# A.侵权行为的主体是指实施侵权行为的人，包括自然人和法人
# B.实施行为必须是以生产经营为目的
# C.侵权行为客观表现为行为人违反专利法规定，以不正当手段侵犯他人专利权
# D.侵权行为主体与侵权责任主体具有一致性
# 参考答案：D
# 参考解析：
# 侵权行为的主体是指实施侵权行为的人，包括自然人和法人。行为人所实施的行为必须是以生产经营为目的，客观上表现为行为人违反《专利法》的规定，以不正当手段侵犯他人专利权。在实践中，侵权行为的主体并不一定是侵权责任的主体，比如未成年人的父母可能会因未成年人的侵犯专利权行为而承担责任，用人单位可能因其职员为了职务之便的专利侵权行为而承担责任。
# 2.关于侵犯专利权责任的说法，错误的是（）。
# A.专利侵权责任包括民事责任、行政责任与刑事责任
# B.专利侵权责任以民事责任为主
# C.根据我国现行法律规定，需承担刑事责任的只有假冒专利构成犯罪的行为
# D.所有侵犯专利权的行为都会导致行政责任
# 参考答案：D
# 参考解析：
# 专利权属于一种民事权利，侵犯专利权的法律责任主要体现为民事责任。但是，部分侵犯专利权的行为不仅仅侵害专利权人的合法权益，还会损害专利秩序及社会公共利益，因此会产生行政责任或（和）刑事责任。并非所有侵犯专利权的行为都会导致行政责任，侵犯专利权的行政责任只适用于假冒专利行为。刑事责任只适用于犯罪行为，因此侵犯专利权的刑事责任仅适用于侵犯专利权的犯罪行为。
# 3.与一般科技文献相比，下列不是专利文献特点的是（）。
# A.传播最新科技信息
# B.集技术、法律、经济信息于一体
# C.披露最新理论发现
# D.格式规范统一、具有统一的分类体系
# 参考答案：C
# 参考解析：
# 专利文献是指根据世界各国专利法规定的格式要求和内容要求撰写，专门记载用于申请专利的具体技术方案的文献。专利文献作为科学技术知识的一种记录，包含了丰富的信息资源。不管是哪国的专利文献，在专利说明书的扉页上，都必须标注专利题目、专利申请人、专利分类号、专利发明人、发明的年代（优先权时间）、专利说明书摘要等著录项目。对这些规范的数据项进行统计，可以反映各个国家或专利权人在不同时期、不同领域技术活动产出和知识产权保护战略。理论发现不是专利法保护的客体，因此不会记载在专利文献中。
# 您的现状是？
# 填写信息，获取结果
# 鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：
# 信息收集范围
# 我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：
# 1、您在使用我们服务时主动提供的信息
# (1)您在网站上报名填写的姓名、电话、住址、微信/QQ、备注等信息。
# (2)您通过电话咨询方式提供的姓名、电话、住址、微信/QQ、备注等信息。
# (3)您在使用网上咨询服务所提供的姓名、电话、住址、微信/QQ、备注等信息。
# (4)您参与我们线上活动时填写的调查问卷中可能包含您的姓名、电话、地址等信息。
# 我们的部分服务可能需要您提供特定的个人敏感信息来实现特定功能。
# 若您选择不提供该类信息，则可能无法正常使用服务中的特定功能，但不影响您使用服务中的其他功能。
# 若您主动提供您的个人敏感信息，即表示您同意我们按本政策所述目的和方式来处理您的个人敏感信息。
# 本次报名服务由上海经济师网提供，本站不承担由于内容的不一致性所引起的一切争议和法律责任，报名结果以最终报名系统所填写的信息为准。
# 信息使用用途
# 我们严格遵守法律法规的规定及与用户的约定，将收集的信息用于以下用途。若我们超出以下用途使用您的信息，我们将再次向您进行说明，并征得您的同意。
# 1、向您提供服务。
# 2、满足您的个性化需求。例如，技能提升规划、学历提升培训等。
# 3、项目开发和服务优化。例如，通过您的咨询问题及服务过程中您的建议等，优化我们的服务。
# 4、向您推荐您可能感兴趣的资讯等。
# 5、项目推荐。例如，我们会根据您的具体要求以及您所具备的条件向您推荐合适的项目。
# 为了让您有更好的体验、改善我们的服务或经您同意的其他用途，在符合相关法律法规的前提下，我们可能将通过某些服务所收集的信息用于我们的其他服务。例如，将您在使用我们某项服务时的信息，用于另一项服务中向您展示个性化的内容或广告、用于用户研究分析与统计等服务。
# 信息保护
# 我们仅在本《隐私政策》所述目的所必需的期间和法律法规要求的时限内保留您的个人信息。
# 本网站将对您所提供的资料进行严格的管理及保护，本网站将使用相应的技术，防止您的个人资料丢失、被盗用或遭篡改。
# 当政府机关依照法定程序要求本网站披露个人资料时，本网站将根据执法单位之要求或为公共安全之目的提供个人资料。在此情况下之任何披露，本网站均得免责。
# 由于您将用户密码告知他人或与他人共享注册帐户，由此导致的任何个人资料泄露。任何由于计算机问题、黑客政击、计算机病毒侵入或发作、因政府管制而造成的暂时性关闭等影响网络正常经营之不可抗力而造成的个人资料泄露、丢失、被盗用或被篡改情况时本网站亦毋需承担任何责任。
# 未成年人保护
# 本网站将建立和维持一合理的程序，以保护未成年人个人资料的保密性及安全性。本网站郑重声明：任何16岁以下的未成年人参加网上活动应事先得到家长或其法定监护人的可经查证的同意。若您是未成年人的监护人，当您对您所监护的未成年人的个人信息有相关疑问时，请通过与我们联系。
# 适用范围
# 我们的所有服务均适用本政策。但某些服务有其特定的隐私指引/声明，该特定隐私指引/声明更具体地说明我们在该服务中如何处理您的信息。如本政策与特定服务的隐私指引/声明有不一致之处，请以该特定隐私指引/声明为准。
# 您必须完全同意以上协议才能使用本网站的在线报名服务。
# (一）由于考试政策等各方面情况的不断调整与变化，本网站所提供的考试信息仅供参考，请以权威部门公布的正式信息为准。
# (二）本网站在文章内容来源出处标注为其他平台的稿件均为转载稿，免费转载出于非商业性学习目的，版权归原作者所有。如您对内容、版权等问题存在异议请于我们联系，我们会及时处理。
# 转载请注明：文章转载自https://www.shjjsw.net/
# 本文地址：https://www.shjjsw.net/show-1234-10123-1.html
# 2023年上海经济师便捷服务
# 经济师培训报名入口
# 备考资料领取入口
# 上海经济师报名指导入口
# 考生交流群
# 微信公众号
# 扫一扫加入微信交流群
# 扫一扫关注微信公众号
# {'question': '.关于专利侵权构成要件的说法，错误的是（）。\nA.侵权行为的主体是指实施侵权行为的人，包括自然人和法人\nB.实施行为必须是以生产经营为目的\nC.侵权行为客观表现为行为人违反专利法规定，以不正当手段侵犯他人专利权\nD.侵权行为主体与侵权责任主体具有一致性\n', 'answer': '参考答案：D\n参考解析：\n侵权行为的主体是指实施侵权行为的人，包括自然人和法人。行为人所实施的行为必须是以生产经营为目的，客观上表现为行为人违反《专利法》的规定，以不正当手段侵犯他人专利权。在实践中，侵权行为的主体并不一定是侵权责任的主体，比如未成年人的父母可能会因未成年人的侵犯专利权行为而承担责任，用人单位可能因其职员为了职务之便的专利侵权行为而承担责任。\n'}
# {'question': '.关于侵犯专利权责任的说法，错误的是（）。\nA.专利侵权责任包括民事责任、行政责任与刑事责任\nB.专利侵权责任以民事责任为主\nC.根据我国现行法律规定，需承担刑事责任的只有假冒专利构成犯罪的行为\nD.所有侵犯专利权的行为都会导致行政责任\n', 'answer': '参考答案：D\n参考解析：\n专利权属于一种民事权利，侵犯专利权的法律责任主要体现为民事责任。但是，部分侵犯专利权的行为不仅仅侵害专利权人的合法权益，还会损害专利秩序及社会公共利益，因此会产生行政责任或（和）刑事责任。并非所有侵犯专利权的行为都会导致行政责任，侵犯专利权的行政责任只适用于假冒专利行为。刑事责任只适用于犯罪行为，因此侵犯专利权的刑事责任仅适用于侵犯专利权的犯罪行为。\n'}
# {'question': '.与一般科技文献相比，下列不是专利文献特点的是（）。\nA.传播最新科技信息\nB.集技术、法律、经济信息于一体\nC.披露最新理论发现\nD.格式规范统一、具有统一的分类体系\n', 'answer': '参考答案：C\n参考解析：\n专利文献是指根据世界各国专利法规定的格式要求和内容要求撰写，专门记载用于申请专利的具体技术方案的文献。专利文献作为科学技术知识的一种记录，包含了丰富的信息资源。不管是哪国的专利文献，在专利说明书的扉页上，都必须标注专利题目、专利申请人、专利分类号、专利发明人、发明的年代（优先权时间）、专利说明书摘要等著录项目。对这些规范的数据项进行统计，可以反映各个国家或专利权人在不同时期、不同领域技术活动产出和知识产权保护战略。理论发现不是专利法保护的客体，因此不会记载在专利文献中。\n您的现状是？\n填写信息，获取结果\n鉴于网络的特性，本网站将无可避免地与您产生直接或间接的互动关系，故特此说明本网站对用户个人信息所采取的收集、使用和保护政策，请您务必仔细阅读：\n信息收集范围\n我们根据合法、正当、必要的原则，仅收集为您提供服务所必要的信息。包括：\n'}

# %%
books_2022 = ['2022初级经济师知识产权日常练习试题：著作权 - 上海经济师.html','2022初级经济师知识产权日常练习试题：地理标志 - 上海经济师.html']
f11 = open("知识产权保护题库合集2022_1.json","w",encoding='utf-8')
for i in books_2022:
    html = open(i,'r',encoding='utf8').read()
    file = bs(html,'html.parser')
    title = file.title.string.strip() if file.title else ''
    body = '\n'.join([p.get_text().strip() for p in file.find_all('p')])
    body = re.sub(r"【结尾】(.|\n)*?扫一扫关注微信公众号","",body)
    print(body)
    question = re.findall(r"\d+(\[.*?(?=[答案]))",body,re.S)
    ans = re.findall(r"(\[答案\].*?)(?=\d\[)",body,re.S)
    
    for i in range(0,len(question)):
        q,a = question[i],ans[i]
        q = q.replace("[.单选题]","[单选题]")
        q = q.replace("[.多选题]","[多选题]")
        d = {"question":q,"answer":a}
        f11.write(json.dumps(d,ensure_ascii=False)+"\n")
f11.close()
# Out:
# 专注上海经济师指导服务
# 考经济师认准上海经济师网
# 微信扫码 即开即用
# 【导读】上海经济师整理了2022年初级经济师知识产权日常练习试题;著作权的练习题，我们一起来了解一下吧~【在线咨询】
# 1[.单选题]著作权国际保护的基本原则不包括（）
# A.国民待遇原则
# B.分级保护原则
# C.自动保护原则
# D.独立保护原则
# [答案]B
# [解析]根据著作权的地域性特点，开展著作权贸易的法律前提是：著作权贸易主体双方所在的国家或地区，或者就相互的著作权保护签订过双边、多边协定，或者共同加入了有关著作权保护的国际条约。著作权的国际保护主要遵循《伯尔尼公约》的四条基本原则：①国民待遇原则;②自动保护原则;③独立保护原则;④最低保护原则。
# 2[.单选题]下列关于著作权质押，说法错误的是（）。
# A.债权人为质权人
# B.债务人为出质人
# C.债务人为质权人
# D.第三人为出质人
# [答案]C
# [解析]债权人为质权人，债务人或者第三人为出质人。
# 3[.单选题]在一国国土上，由该国的民族或种族集体创作，经世代相传，不断发展而构成的作品，是指（）。
# A.民间文学艺术作品
# B.艺术作品
# C.文字作品
# D.口述作品
# [答案]A
# [解析]民间文学艺术作品，是指在一国国土上，由该国的民族或种族集体创作，经世代相传，不断发展而构成的作品。一般认为，它包括语言形式（民间故事、民间诗歌）、音乐形式（民歌、民间器乐等）、动作形式（民间舞蹈及戏剧等）以及用物质材料体现的形式（绘画、雕塑、工艺品、编织品等）。
# 4[.单选题]著作权人授权有关组织代为集中管理著作权、邻接权的制度是（）。
# A.行政管理
# B.集体管理
# C.法律管理
# D.组织管理
# [答案]B
# [解析]集体管理是指著作权人授权有关组织代为集中管理著作权、邻接权的制度。
# 5[.单选题]著作权的主体又称（）。
# A.著作者
# B.著作归属人
# C.著作组织
# D.著作权人
# [答案]D
# [解析]本题考查著作权客体、主体。著作权的主体又称著作权人。其它选项为干扰项。
# 6[.单选题]著作人身权的特点不包括（）。
# A.不可剥夺性
# B.个别权能的可继承性
# C.著作人身权的永久性
# D.著作人身权的临时性
# [答案]D
# [解析]本题考查著作权自由人身权。著作人身权的特点包括：1.著作人身权整体的不可转让性;2.不可剥夺性;3.个别权能的可继承性（如发表权）;4.著作人身权的永久性。
# 7[.单选题]作品的作者是法人、其他组织的，保护期限到作者首次发表后第（）。
# A.50年的12月31日
# B.50年的12月30日
# C.60年的12月30日
# D.60年的12月31日
# [答案]A
# [解析]本题考查著作权取得条件和保护期。著作权的保护期限，作品的作者是公民的，保护期限至作者死亡之后第50年的12月31日;作品的作者是法人、其他组织的，保护期限到作者首次发表后第50年的12月31日;但作品自创作完成后50年未发表的，不再受《著作权法》保护。
# 8[.单选题]下列智力成果不属于《著作权法》保护的范围的是（）。
# A.文学
# B.艺术
# C.创意
# D.科学
# [答案]C
# [解析]《著作权法》所规定的“作品”，是指文学、艺术和科学领域内具有独
# 创性并能以某种有形形式复制的智力成果。抽象的思想、观念、创意、构思、概念、操作方法等也不受著作权法保护。
# 9[.单选题]下列属于著作权侵权民事责任的是（）。
# A.罚款
# B.罚金
# C.没收财产
# D.赔偿损失
# [答案]D
# [解析]著作权侵权的民事责任包括停止侵害、赔偿损失、消除影响、赔礼道歉等。
# 10[.单选题]王某于1999年9月9日创作完成了一部小说《十年生死两茫茫》，该小说于2000年2月20日出版，王某于2017年7月7日去世。王某对该小说的著作财产权截止到（）。
# A.2049年9月8日
# B.2049年12月31日
# C.2050年2月19日
# D.2067年12月31日
# [答案]D
# [解析]公民的作品，其著作权中的发表权及著作财产权的保护期为作者终生及其死亡后50年，截止到作者死亡后第50年的12月31日。
# 11[.单选题]根据《著作权法》，下列属于民事责任的是（）。
# A.赔偿损失
# B.罚款
# C.警告
# D.没收违法所得
# [答案]A
# [解析]著作权侵权的民事责任包括停止侵害、赔偿损失、消除影响、赔礼道歉等。
# 12[.单选题]下列权利中，属于著作财产权的是（）。
# A.决定作品是否公之于众的权利
# B.授权他人修改作品的权利
# C.公开陈列美术作品复制件的权利
# D.表明作者身份，在作品上署名的权利
# [答案]C
# [解析]展览权，g卩公开陈列美术作品、摄影作品的原件或者复制件的权利。这是一项仅有美术作品和摄影作品的著作权人才享有的权利，属于著作财产权。美术等作品原件所有权的转移，不视为作品著作权的转移，但美术作品的原件所有人有权对作品进行展览。
# 13[.单选题]下列不受《著作权法》的保护的是（）。
# A.某教授出版的《热点案例选编》
# B.王宝强的代理律师发表的《律师声明》
# C.外语学院教师翻译的《韩国商标法》中文版
# D.国家版权局发布的《出版文字作品报酬规定》
# [答案]D
# [解析]《出版文字作品报酬规定》属于国家机关的文件，不受《著作权法》保护。根据《著作权法》，不受著作权法保护的对象包括：①法律、法规，国家机关的决议、决定、命令和其他具有立法、行政、司法性质的文件，及其官方正式译文。②时事新闻。③历法、通用数表、通用表格和公式。
# 14[.单选题]王某委托李某开发一款设计软件，但双方未约定设计软件的著作权归属，该设计软件的著作权归（）。
# A.王某
# B.李某
# C.王某与李某
# D.约定不明，归国家所有
# [答案]B
# [解析]委托作品的著作权归属由委托人和受托人通过合同约定。合同未作明确约定或者没有订立合同的，著作权属于受托人。
# 15[.单选题]下列行为中，属于著作权合理使用的是（）。
# A.作家甲将已经发表的汉字作品翻译成俄文在俄罗斯出版发行
# B.乙广播电台的主持人直播时向观众诵读了甲已经发表的文章
# C.丙咖啡店购买正版DVD作为该店的背景音乐播放
# D.丁老师复印了一篇已经发表的文章，要求学生写读后感
# [答案]D
# [解析]合理使用，指的是自然人、法人或者其他组织根据法律规定，可以不经著作权人或者邻接权人许可，使用他人已发表作品，且无需支付报酬的一项制度。下列情况都属于合理使用：报纸、期刊、广播电台、电视台等媒体刊登或者播放其他报纸、期刊、广播电台、电视台等媒体已经发表的关于政治、经济、宗教问题的时事性文章;为学校课堂教学或者科学研究，翻译、少量复制或者通过信息网络提供已经发表的作品，供教学或者科研人员使用;将中国公民、法人或者其他组织已经发表的以汉语言文字创作的作品翻译成少数民族语言文字作品在国内出版发行或者通过信息网络提供。
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 14
#      11 ans = re.findall(r"(\[答案\].*?)(?=\d\[)",body,re.S)
#      13 for i in range(0,len(question)):
# ---> 14     q,a = question[i],ans[i]
#      15     q = q.replace("[.单选题]","[单选题]")
#      16     q = q.replace("[.多选题]","[多选题]")
#
# IndexError: list index out of range

# %%
books_2021 = ['2021初级经济师考试《知识产权》章节试题：专利保护 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：专利申请 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：专利运用 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：其他类型的知识产权 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：商业秘密 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：商标使用 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：商标基础 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：地理标志 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：注册商标专用权的保护 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：知识产权基础 - 上海经济师.html','2021初级经济师考试《知识产权》章节试题：著作权 - 上海经济师.html','2021年初级经济师考试知识产权习题：侵犯著作权的行为及其法律责任 - 上海经济师.html','2021年初级经济师考试知识产权习题：商业秘密 - 上海经济师.html','2021年初级经济师考试知识产权习题：商标专用权 - 上海经济师.html','2021年初级经济师考试知识产权习题：地理标志 - 上海经济师.html','2021年初级经济师考试知识产权习题：地理标志保护概述 - 上海经济师.html','2021年初级经济师考试知识产权习题：植物新品种权 - 上海经济师.html','2021年初级经济师考试知识产权习题：著作权的内容 - 上海经济师.html','2021年初级经济师考试知识产权习题：集成电路布图设计专有权 - 上海经济师.html']

# %%
f12 = open('知识产权保护题库合集2021.json',"w",encoding='utf-8')
for i in books_2021:
    html = open(i,'r',encoding='utf8').read()
    file = bs(html,'html.parser')
    title = file.title.string.strip() if file.title else ''
    body = '\n'.join([p.get_text().strip() for p in file.find_all('p')])
    question = re.findall(r"\d+(\[.*?(?=\[答案\]))",body,re.S)
    ans = re.findall(r"(\[答案\].*?)\s",body,re.S)
    for i in range(0,len(question)):
        q,a = question[i],ans[i]
        q=q.replace("[.单选题]","[单选题]")
        d = {"question":q,"answer":a}
        f12.write(json.dumps(d,ensure_ascii=False)+"\n")
f12.close()

# %% [markdown]
# # 智燃-2021专利法考(zhi ran 2021 patent law exam)

# %%
zr_q = open("智燃题目_专利.txt",encoding = 'utf-8').read()
zr_a = open("智燃题目_答案.txt",encoding = 'utf-8').read()

# %%
f13 = open('智燃-2021专利法考.json',"w",encoding='utf-8')
q = re.findall(r"\d+\.(.*?)(?=\n\d+\.)",zr_q,re.S)
a_1 = re.findall(r"\d+．(.*?)(?=\d+．)",zr_a,re.S)
a_2 = re.findall(r"\d+\.(.*?)(?=\d+\.)",zr_a,re.S)
a = []
for i in a_1:
    a.append(i)
for i in a_2:
    a.append(i)

    
for i in range(0,len(q)):
    question = q[i]
    answer = a[i]
    d = {"question":question,"answer":answer}
    f13.write(json.dumps(d,ensure_ascii=False)+"\n")
f13.close()

# %% [markdown]
# # 国产局 知识考题(National Intellectual Property Office Knowledge Test Questions)

# %%
f14 = open('国知局-知产考试题js.json',"w",encoding='utf-8')
gcj_qa = open("国知局-知产考试题.txt",encoding = 'utf-8').read()
gcj_qa = re.sub(r"\d+\.|[A-D]. ","",gcj_qa)

q=re.findall(r"\d+、(.*?)答题",gcj_qa,re.S)
a=re.findall(r"(正确答案.*?)试题解析",gcj_qa,re.S)

for i in range(0,len(q)):
    question = q[i]
    answer = a[i]
    d = {"question":question,"answer":answer}
    f14.write(json.dumps(d,ensure_ascii=False)+"\n")
f14.close()

# %% [markdown]
# # 消防知识-考题

# %%
df_stext = pd.read_excel('fire_knowledge.xlsx')
fw_safe = open("消防知识-考题.json","w",encoding='utf-8') 
for i in range(len(df_stext)):
    d = df_stext.iloc[i]
    URL = d[0] 
    question = d[1]
    answer = d[2]
    dw = {}
    dw["URL"] = URL
    dw["question"] = question
    dw["answer"] = answer
    fw_safe.write(json.dumps(dw,ensure_ascii=False)+"\n")
fw_safe.close()

# %%
import json
import pandas as pd
dsd = open("消防知识-考题.json",'r',encoding='utf-8').readlines()
f15 = open("消防知识-考题_clean.json","w",encoding='utf-8')
for line in dsd:
    item = json.loads(line)
    if 'question' in item:
        item['question']=item['question'].replace('所属题库：消防知识\t\t\t   \n\t\t\t   \n\t\t\t   \n\t\t\t   【单选】\n        \t\t\t\t\t   ',"")
        item['question']=item['question'].replace('\n\t\t\t\t',"")
        item['question']=item['question'].replace('\n\t\t\t\t\t',"")
        item['question']=item['question'].replace('\n\t\t\t'," ")
        item['question']=item['question'].replace('            \t \n            \t ',"")
        item['question']=item['question'].replace('    \t        \t',"")
        item['question']=item['question'].replace('所属题库：消防知识\t\t\t                       \t\t 【多选】\n        \t\t\t\t\t',"")
        item['question']=item['question'].replace('所属题库：消防知识\t\t\t                       \t\t 【判断】\t\t\t  ',"")
        item['question']=item['question'].strip()
        f15.write(json.dumps(item,ensure_ascii=False)+"\n")
f15.close()

# %% [markdown]
# # 安全知识-考题

# %%
df_stext = pd.read_excel('safe_knowledge_.xlsx')
fw_safe = open("安全知识-考题.json","w",encoding='utf-8') 
for i in range(len(df_stext)):
    d = df_stext.iloc[i]
    URL = d[0] 
    question = d[1]
    answer = d[2]
    dw = {}
    dw["URL"] = URL
    dw["question"] = question
    dw["answer"] = answer
    fw_safe.write(json.dumps(dw,ensure_ascii=False)+"\n")
fw_safe.close()

# %%
import json
import pandas as pd
dsd = open("安全知识-考题.json",'r',encoding='utf-8').readlines()
f16 = open("安全知识-考题_clean.json","w",encoding='utf-8')
for line in dsd:
    item = json.loads(line)
    if 'question' in item:
        item['question']=item['question'].replace('所属题库：安全知识\t\t\t   \n\t\t\t   \n\t\t\t   \n\t\t\t   【单选】\n        \t\t\t\t\t   ',"")
        item['question']=item['question'].replace('\t\t 【多选】\n        \t\t\t\t\t',"")
        item['question']=item['question'].replace('所属题库：安全知识\t\t\t',"")
        item['question']=item['question'].replace('所属题库：安全知识\t\t\t                       \t\t 【判断】\t\t\t   ',"")
        item['question']=item['question'].replace('\n\t\t\t\t',"  ")
        item['question']=item['question'].replace('\n\t\t\t\t\t',"  ")
        item['question']=item['question'].replace('\n\t\t\t'," ")
        item['question']=item['question'].replace("                          ","")
        item['question']=item['question'].replace('            \t \n            \t ',"  ")
        item['question']=item['question'].replace('    \t        \t',"  ")
        item['question']=item['question'].replace('    \t        \t',"  ")
        item['question']=item['question'].replace("                       \t\t 【判断】\t\t\t   ","")
        item['question']=item['question'].strip()
        f16.write(json.dumps(item,ensure_ascii=False)+"\n")
f16.close()

# %% [markdown]
# # 民法典-考题

# %%
df_mtext = pd.read_excel('minfadian.xlsx')
fw_min = open("民法典考题.json","w",encoding='utf-8') 
for i in range(len(df_mtext)):
    d = df_mtext.iloc[i]
    URL = d[0] 
    question = d[1]
    answer = d[2]
    dw = {}
    dw["URL"] = URL
    dw["question"] = question
    dw["answer"] = answer
    fw_min.write(json.dumps(dw,ensure_ascii=False)+"\n")
fw_min.close()

# %%
import json
import pandas as pd
dsd = open("民法典考题.json",'r',encoding='utf-8').readlines()
f17 = open("民法典考题_clean.json","w",encoding='utf-8')
for line in dsd:
    item = json.loads(line)
    if 'question' in item:
        item['question']=item['question'].replace("所属题库：民法典\t\t\t   \n\t\t\t   \n\t\t\t   \n\t\t\t   【单选】\n        \t\t\t\t\t   ","")
        item['question']=item['question'].replace("\n\t\t\t   \t\n\t\t\t   \n\t\t\t   \t","  ")
        item['question']=item['question'].replace("\n\t\t\t\t","  ")
        item['question']=item['question'].replace("所属题库：民法典\t\t\t   \n\t\t\t   \n\t\t\t   \n\t\t\t           \t\t 【多选】\n        \t\t\t\t\t   ","  ")
        item['question']=item['question'].replace("            \t \n            \t ","  ")
        item['question']=item['question'].replace("所属题库：民法典\t\t\t   \n\t\t\t   \n\t\t\t   \n\t\t\t           \t\t 【判断】\t\t\t   ","  ")
        item['question']=item['question'].strip()
        f17.write(json.dumps(item,ensure_ascii=False)+"\n")
f17.close()

# %% [markdown]
# # zy_2000_exam

# %%
import pandas as pd
import json

zy_2000_exam = pd.read_csv('zy_2000_exam.csv')

f_zy_2000_exam = open("zy_2000_exam.json","w",encoding='utf-8')

print(len(zy_2000_exam))


for i in range(len(zy_2000_exam)):
    line = zy_2000_exam.iloc[i]
    subject=line[0]
    answer = line[3].replace("[","").replace("]","")
    
    if line[5]=="\n":
        output = "答案: "+ answer
    else:
        output = "解析："+line[5]+"答案: "+ answer
        
    d = {"input":subject,"target":output}
    f_zy_2000_exam.write(json.dumps(d,ensure_ascii=False) + "\n")
# Out:
# 2941

# %% [markdown]
# # fakao

# %%
import json
import pandas as pd
import os
folder_path = "/Users/shenxunyu/fakao"
file_names = os.listdir(folder_path)
# OUT(liST):["1.JSON","2.JOSN","3.JSON",...]
 
# 学习下python的基本语法，包括：文件的写入（w（+）,r（+）,a（+））、open() 和 with open 、变量 、调试等、os、sys、josn dunp dumps load loads 、
# 相关路径、绝对路径

json_files = []
f_fakao = open("f_fakao.json","w",encoding='utf-8')

# <1>
# 读取储存文件，文件为空，无效操作
# read_fakao = open("f_fakao.json",'r',encoding='utf-8').readlines()

# python变量不用事先定义
# C/c++ 变量需要事先定义
#explanation = ""

# <2> 地址名称错误、不确认文件地址位置用绝对路径 
# 项目用下相对路径，代码交付给他人能顺利运行。
# PYTHON 的相对路径 ../PATH

# <3> 读文件名错误时，用文件名称过滤。
# file_name.endswith(".json"): 
# startswith 
# in
for file_name in file_names:
        if file_name.endswith(".json"):
            json_files.append(folder_path+"/"+file_name)


read_fakao = []
for i in json_files:
    dsd_fa = open(i,'r',encoding='utf-8').readlines()
    read_fakao += dsd_fa

print(len(read_fakao))
num = 0
#len(read_fakao)
for i in range(len(read_fakao)):
    if not read_fakao[i]:continue
    try:
        line = json.loads(read_fakao[i])
    except:
        print(json.loads(read_fakao[i]))
        raise
    q= line["Question"]
    o = line["Options"]
    choi = "A. "+o["a"]+ "\nB. "+o["b"]+"\nC. "+o["c"]+"\nD. "+o["d"]
    ans = re.sub(r"\[|\]","",line["Answer"][0])
    explanation = line["Reason of Question"]
    explanation = re.sub(r"【","",explanation)
    explanation = re.sub(r"】",": ",explanation)
    inp =  q +"\n"+ choi
    oup = explanation+"\n答案："+ans
    d = {"input":inp,"target":oup}
    num = num + 1
    f_fakao.write(json.dumps(d,ensure_ascii=False) + "\n")
# Out:
# 9975
